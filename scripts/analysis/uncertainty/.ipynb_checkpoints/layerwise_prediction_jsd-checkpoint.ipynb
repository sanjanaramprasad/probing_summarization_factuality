# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
df_genaudit  = pd.read_csv('/home/ramprasad.sa/probing_summarization_factuality/datasets/Genaudit_annotations.csv')
df_genaudit['docid_processed'] = [row['id'].split('#')[-1] for idx, row in df_genaudit.iterrows()]
df_genaudit.head()

df = df_genaudit[df_genaudit['model'] == 'llama7b']
df = df[df['origin'] == 'REDDIT']
# df[~df['annotated_spans'].isnull()]
df
# Out:
#      Unnamed: 0                                     id  \
# 3             3     Rachel Usher#REDDIT-83:llama7b-ul2
# 9             9     Rachel Usher#REDDIT-54:llama7b-ul2
# 84           84  Cynthia Lamanda#REDDIT-73:llama7b-ul2
# 88           88     Rachel Usher#REDDIT-19:llama7b-ul2
# 100         100     Rachel Usher#REDDIT-18:llama7b-ul2
# 128         128  Cynthia Lamanda#REDDIT-61:llama7b-ul2
# 161         161  Cynthia Lamanda#REDDIT-76:llama7b-ul2
# 176         176  Cynthia Lamanda#REDDIT-23:llama7b-ul2
# 182         182      Rachel Usher#REDDIT-6:llama7b-ul2
# 194         194  Cynthia Lamanda#REDDIT-51:llama7b-ul2
# 209         209  Cynthia Lamanda#REDDIT-13:llama7b-ul2
# 215         215  Cynthia Lamanda#REDDIT-14:llama7b-ul2
# 229         229     Rachel Usher#REDDIT-41:llama7b-ul2
# 238         238  Cynthia Lamanda#REDDIT-39:llama7b-ul2
# 279         279     Rachel Usher#REDDIT-38:llama7b-ul2
# 294         294  Cynthia Lamanda#REDDIT-48:llama7b-ul2
# 310         310  Cynthia Lamanda#REDDIT-50:llama7b-ul2
# 314         314     Rachel Usher#REDDIT-21:llama7b-ul2
# 363         363   Cynthia Lamanda#REDDIT-3:llama7b-ul2
# 393         393      Rachel Usher#REDDIT-8:llama7b-ul2
# 412         412  Cynthia Lamanda#REDDIT-17:llama7b-ul2
# 439         439     Rachel Usher#REDDIT-80:llama7b-ul2
# 448         448      Rachel Usher#REDDIT-9:llama7b-ul2
# 454         454  Cynthia Lamanda#REDDIT-34:llama7b-ul2
# 471         471  Cynthia Lamanda#REDDIT-12:llama7b-ul2
# 508         508     Rachel Usher#REDDIT-37:llama7b-ul2
# 539         539     Rachel Usher#REDDIT-31:llama7b-ul2
# 563         563  Cynthia Lamanda#REDDIT-72:llama7b-ul2
# 619         619     Rachel Usher#REDDIT-78:llama7b-ul2
# 659         659     Rachel Usher#REDDIT-79:llama7b-ul2
#
#                                                 source  \
# 3    both me and my girlfriend participate in winte...
# 9    i thought my act test was today.. it was yeste...
# 84   this fuckup is currently ongoing, as i'm in a ...
# 88   this happened earlier this week, but has only ...
# 100  this happened when i was about 9 years old and...
# 128  this happened many years ago.. i was on my bik...
# 161  it's my wife's birthday in 2 weeks so i decide...
# 176  my eight hours standing at a register were com...
# 182  little background: i work as a part-time clerk...
# 194  i was able to get a preorder in for the fallou...
# 209  so unlike the majority of posts i see here thi...
# 215  i have a classmate who is really interested in...
# 229  this happened a week or two ago.. i was in sco...
# 238  one day, when i was a lot younger (although no...
# 279  this happened earlier today around noon.. i ha...
# 294  this just happened, and i had to compose mysel...
# 310  this actually happened on saturday but whateve...
# 314  this story actually happened a good few years ...
# 363  this happened in the past.. my co-workers and ...
# 393  i'd like to preface this by saying i'm an ipho...
# 412  so this just happened a couple of hours ago.. ...
# 439  **backstory:** there is this lady who comes by...
# 448  semi obligatory to say that this did not happe...
# 454  i work in a secure mental health hospital in t...
# 471  this was about a week or two ago but i still t...
# 508  context: i've recently come down with a pretty...
# 539  today i made a $4,000 fuck up.. my "mnt req" l...
# 563  tifu, but actually this happened a few weeks a...
# 619  some background information first; i'm in high...
# 659  this technically happened today, but started l...
#
#                                                summary  \
# 3    The writer and their girlfriend are both invol...
# 9    A person realized their ACT test was scheduled...
# 84   A person attempted to clean their earrings wit...
# 88   Aussie football fan purchased tickets to a maj...
# 100  A 9-year-old boy caught a praying mantis in hi...
# 128  A person was riding their bike on a deck when ...
# 161  A man bought his wife an expensive Cartier ite...
# 176  The author spent eight hours working at a regi...
# 182  A part-time grocery store clerk shared a recen...
# 194  A user attempted to preorder the Fallout 4 Pip...
# 209  A person wrote about an incident where they qu...
# 215  A student wrote in about an incident where the...
# 229  A personal account of climbing Ben Nevis, the ...
# 238  The author, when younger, tried to melt a cray...
# 279  A man accidentally threw a plate instead of a ...
# 294  A customer gave us the wrong address to ship a...
# 310  took shots with friends, brother wanted to sho...
# 314  A teenager was playing with friends in the gar...
# 363  A man and his coworkers go out for karaoke on ...
# 393  ** The writer is an iPhone user who was disapp...
# 412  A couple was on their way back from a doctor's...
# 439  A man's attempt to deliver a bag of recyclable...
# 448  A college student's laptop hard drive fails, c...
# 454  A mental health worker at a secure hospital in...
# 471  A young athlete experienced a humorous mistake...
# 508  A user has come down with an inner ear infecti...
# 539  A young man attempted to change his truck's oi...
# 563  The author signed up for Reddit Secret Santa b...
# 619  The writer has been crushing on a girl named S...
# 659  A student worked on an annotated bibliography ...
#
#                                        annotated_spans    model  origin  \
# 3    is late<sep>bus and doesn't realize that their...  llama7b  REDDIT
# 9                                                  NaN  llama7b  REDDIT
# 84   the earrings being exposed to light<sep>causin...  llama7b  REDDIT
# 88                                                 NaN  llama7b  REDDIT
# 100                     molted and had grown new wings  llama7b  REDDIT
# 128                                           the bike  llama7b  REDDIT
# 161                                                NaN  llama7b  REDDIT
# 176                                            younger  llama7b  REDDIT
# 182                                                NaN  llama7b  REDDIT
# 194                       charged for the<sep>preorder  llama7b  REDDIT
# 209                                                NaN  llama7b  REDDIT
# 215                              make<sep>hearing loss  llama7b  REDDIT
# 229                                                NaN  llama7b  REDDIT
# 238                                                NaN  llama7b  REDDIT
# 279                                 man<sep>instead of  llama7b  REDDIT
# 294                                                NaN  llama7b  REDDIT
# 310                                            Vomited  llama7b  REDDIT
# 314                                                NaN  llama7b  REDDIT
# 363                            the song's release date  llama7b  REDDIT
# 393                                                NaN  llama7b  REDDIT
# 412  driver of the car that was hit in the rear qua...  llama7b  REDDIT
# 439                                                NaN  llama7b  REDDIT
# 448            and accessing important files<sep>today  llama7b  REDDIT
# 454                                             brings  llama7b  REDDIT
# 471                                         a humorous  llama7b  REDDIT
# 508                                                NaN  llama7b  REDDIT
# 539                                      several miles  llama7b  REDDIT
# 563                    their parents<sep>their parents  llama7b  REDDIT
# 619                                           next day  llama7b  REDDIT
# 659                                                NaN  llama7b  REDDIT
#
#            docid_processed
# 3    REDDIT-83:llama7b-ul2
# 9    REDDIT-54:llama7b-ul2
# 84   REDDIT-73:llama7b-ul2
# 88   REDDIT-19:llama7b-ul2
# 100  REDDIT-18:llama7b-ul2
# 128  REDDIT-61:llama7b-ul2
# 161  REDDIT-76:llama7b-ul2
# 176  REDDIT-23:llama7b-ul2
# 182   REDDIT-6:llama7b-ul2
# 194  REDDIT-51:llama7b-ul2
# 209  REDDIT-13:llama7b-ul2
# 215  REDDIT-14:llama7b-ul2
# 229  REDDIT-41:llama7b-ul2
# 238  REDDIT-39:llama7b-ul2
# 279  REDDIT-38:llama7b-ul2
# 294  REDDIT-48:llama7b-ul2
# 310  REDDIT-50:llama7b-ul2
# 314  REDDIT-21:llama7b-ul2
# 363   REDDIT-3:llama7b-ul2
# 393   REDDIT-8:llama7b-ul2
# 412  REDDIT-17:llama7b-ul2
# 439  REDDIT-80:llama7b-ul2
# 448   REDDIT-9:llama7b-ul2
# 454  REDDIT-34:llama7b-ul2
# 471  REDDIT-12:llama7b-ul2
# 508  REDDIT-37:llama7b-ul2
# 539  REDDIT-31:llama7b-ul2
# 563  REDDIT-72:llama7b-ul2
# 619  REDDIT-78:llama7b-ul2
# 659  REDDIT-79:llama7b-ul2

# %%
model_path = {'mistral7b': 'mistralai/Mistral-7B-Instruct-v0.1',
             'falcon7b': 'tiiuae/falcon-7b-instruct',
              'llama7b': '/work/frink/models/llama_2_7b_chat_hf',
             'flanul2': 'google/flan-ul2'}

def load_tokenizer(model_name):
    tokenizer = AutoTokenizer.from_pretrained(model_path[model_name],
                                         cache_dir = '/scratch/ramprasad.sa/huggingface_models')
    return tokenizer

def refine_df(df_path):
    df = pd.read_csv(df_path)
    #### since teacher forcing, make sure to only use rows where predicted is same as prev generated
    df['target_token_id'] = [eval(row['target_token'].split('_')[-1]) for idx, row in df.iterrows()]
    df = df[df['target_token_id'] == df['pred_token_layer32']]
    return df

def read_model_probabilities_df(model_name, origin):
    data_path = f'/scratch/ramprasad.sa/probing_summarization_factuality/metric_scores/Genaudit/layer_wise_uncertainty_{model_name}_{origin}_document_context.csv'
    df_model = refine_df(data_path)
    tokenizer = load_tokenizer(model_name)
    df_model['model'] = [model_name] * len(df_model)
    return tokenizer, df_model

falcon_tokenizer, df_falcon_xsum = read_model_probabilities_df('falcon7b', 'XSUM')
llama_tokenizer, df_llama_xsum = read_model_probabilities_df('llama7b', 'XSUM')
mistral_tokenizer, df_mistral_xsum = read_model_probabilities_df('mistral7b', 'XSUM')
print(len(set(df_falcon_xsum['docid'])), len(set(df_llama_xsum['docid'])), len(set(df_mistral_xsum['docid'])))


mistral_tokenizer, df_mistral_acibench = read_model_probabilities_df('mistral7b', 'ACIBENCH')
falcon_tokenizer, df_falcon_acibench = read_model_probabilities_df('falcon7b', 'ACIBENCH')
llama_tokenizer, df_llama_acibench = read_model_probabilities_df('llama7b', 'ACIBENCH')

mistral_tokenizer, df_mistral_reddit = read_model_probabilities_df('mistral7b', 'REDDIT')
falcon_tokenizer, df_falcon_reddit = read_model_probabilities_df('falcon7b', 'REDDIT')
llama_tokenizer, df_llama_reddit = read_model_probabilities_df('llama7b', 'REDDIT')
print(len(set(df_mistral_reddit['docid'])), len(set(df_falcon_reddit['docid'])), len(set(df_llama_reddit['docid'])))
# Out:
# /home/ramprasad.sa/.conda/envs/probe/lib/python3.8/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/ramprasad.sa/.conda/envs/probe/lib/python3.8/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 30 30 30
# /home/ramprasad.sa/.conda/envs/probe/lib/python3.8/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/ramprasad.sa/.conda/envs/probe/lib/python3.8/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/ramprasad.sa/.conda/envs/probe/lib/python3.8/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/ramprasad.sa/.conda/envs/probe/lib/python3.8/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 30 26 30

# %%
df_all_models_xsum = pd.concat([df_falcon_xsum, df_llama_xsum, df_mistral_xsum])
df_all_models_acibench = pd.concat([df_falcon_acibench, df_llama_acibench, df_mistral_acibench])
df_all_models_reddit = pd.concat([df_falcon_reddit, df_llama_reddit, df_mistral_reddit])

print(len(df_all_models_xsum))
df_all_models_acibench.head()
df_all_models = pd.concat([df_all_models_xsum, df_all_models_acibench, df_all_models_reddit])
docids = list(df_all_models['docid'].values)
docids = [each.split('#')[-1].split('-')[0] for each in docids]
df_all_models['origin'] = docids
df_all_models.head()
# Out:
# 7656
# /tmp/ipykernel_20449/274592062.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_all_models['origin'] = docids
#    Unnamed: 0                                target_token  label  \
# 1           0   f5e3fd93-4a51-41d1-bbee-95df37e62e07_3787      0
# 2           0  13311b7f-35ef-41e1-9ab0-a44486b3eae8_42402      0
# 3           0   fe7ef2d9-6153-49a3-bd33-bc5014f8a1b4_1135      0
# 4           0   c27700b2-52f7-4846-9624-81371547692e_4497      0
# 5           0  ac627bdb-0c54-422f-b174-9ca6363f610b_13384      0
#
#    prev_hidden_state_sim_layer1  prev_hidden_state_sim_layer2  \
# 1                      0.087404                      0.902840
# 2                      0.099551                      0.869240
# 3                      0.093394                      0.833900
# 4                      0.054801                      0.820559
# 5                      0.121113                      0.766579
#
#    prev_hidden_state_sim_layer3  prev_hidden_state_sim_layer4  \
# 1                      0.893597                      0.929759
# 2                      0.945129                      0.919445
# 3                      0.868841                      0.864377
# 4                      0.903625                      0.910642
# 5                      0.750057                      0.858033
#
#    prev_hidden_state_sim_layer5  prev_hidden_state_sim_layer6  \
# 1                      0.942955                      0.880105
# 2                      0.949189                      0.895772
# 3                      0.937902                      0.926948
# 4                      0.937008                      0.837402
# 5                      0.901822                      0.876636
#
#    prev_hidden_state_sim_layer7  ...  entropy_layer32  pred_prob_layer32  \
# 1                      0.896535  ...         0.032241           0.996724
# 2                      0.914660  ...         0.007364           0.999346
# 3                      0.926052  ...         0.006457           0.999557
# 4                      0.905605  ...         0.169321           0.987571
# 5                      0.918694  ...         0.005929           0.999612
#
#    pred_token_layer32  target_prob_layer32  \
# 1                3787             0.996724
# 2               42402             0.999346
# 3                1135             0.999557
# 4                4497             0.987571
# 5               13384             0.999612
#
#                         top3_predicted_probs_layer32  \
# 1  [0.9967244267463684, 0.001467414665967226, 0.0...
# 2  [0.9993461966514587, 0.00038860522909089923, 5...
# 3  [0.9995569586753845, 4.4483716919785365e-05, 2...
# 4  [0.9875713586807251, 0.0006436973344534636, 0....
# 5  [0.9996116757392883, 4.5011060137767345e-05, 3...
#
#    top3_predicted_tokens_layer32                                       docid  \
# 1             [3787, 13384, 302]  Cynthia Lamanda#XSUM-19389161:falcon7b-ul2
# 2              [42402, 1615, 85]  Cynthia Lamanda#XSUM-19389161:falcon7b-ul2
# 3            [1135, 13384, 3081]  Cynthia Lamanda#XSUM-19389161:falcon7b-ul2
# 4              [4497, 286, 7508]  Cynthia Lamanda#XSUM-19389161:falcon7b-ul2
# 5          [13384, 16789, 42451]  Cynthia Lamanda#XSUM-19389161:falcon7b-ul2
#
#    target_token_id     model  origin
# 1             3787  falcon7b    XSUM
# 2            42402  falcon7b    XSUM
# 3             1135  falcon7b    XSUM
# 4             4497  falcon7b    XSUM
# 5            13384  falcon7b    XSUM
#
# [5 rows x 270 columns]

# %%
set(df_all_models['origin'].values)
# Out:
# {'ACIBENCH', 'REDDIT', 'XSUM'}

# %%
set(df_all_models[df_all_models['model'] == 'mistral7b']['origin'].values)
# Out:
# {'ACIBENCH', 'REDDIT', 'XSUM'}

# %%
from random import sample 
import torch
import torch.nn.functional as F
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def get_sample_doc(model,
                   origin,
                   tokenizer):
    df_model_origin = df_all_models[(df_all_models['model'] == model) & (df_all_models['origin'] == origin)]
    ### make sure to include nonfactual 
    df_model_origin_nonfactual = df_model_origin[df_model_origin['label'] == 1]
    sample_doc = sample(list(set(df_model_origin_nonfactual['docid'])), 1)

    df_sample_doc = df_model_origin[df_model_origin['docid'] == sample_doc[0]]
    nonfactual_idx_vals = [idx for idx, lab in enumerate(df_sample_doc['label'].values) if lab == 1]
    print('SUMMARY', tokenizer.decode(df_sample_doc['pred_token_layer32']))
    return df_sample_doc, nonfactual_idx_vals

def make_heatmap_plot_data(df_sample_doc,
                      start_idx, 
                     end_idx,
                     num_layers = 32,
                     ranked_pred = False):
    sample_data = {
    'token_name': [],
    }

    sample_data_predictions = {}

    for layer_num in range(2,num_layers, 2):
        sample_data[f'layer_{layer_num}'] = []
        sample_data_predictions[f'layer_{layer_num}'] = []

    row_counter = 0
    for idx, row in df_sample_doc.iterrows():
        token = tokenizer.decode(row['pred_token_layer32'])
        label = row['label']
        # print(token, label)
        if row_counter >= start_idx and row_counter <= end_idx :
            label_str = 'factual' if label == 0 else 'nonfactual'
            sample_data['token_name'] += [f'{row_counter}-{token} ({label_str})']
            row_jsds = [row[column] for column in row.keys() if 'jsd' in column]
            row_jsds = F.softmax(torch.tensor(row_jsds), dim = -1)
            row_label = row['label']
            row_label = 'factual' if row_label == 0 else 'non_factual'

            final_layer_prediction = row[f'pred_token_layer32']
            final_layer_prediction_str = tokenizer.decode(final_layer_prediction)
            for layer_num in range(2, num_layers, 2):
                top_layer_tokens = eval(row[f'top3_predicted_tokens_layer{layer_num}'])
                layer_prediction = row[f'pred_token_layer{layer_num}']
                layer_prediction_str = tokenizer.decode(layer_prediction)

                rank = -1
                if final_layer_prediction in top_layer_tokens:
                    # print(row[f'pred_token_layer{layer_num}'], top_layer_tokens)
                    rank = top_layer_tokens.index(final_layer_prediction) + 1


                final_ranked = f'{final_layer_prediction_str}-{rank}' if rank > -1 else 'NF'
                jsd_layer = row[f'jsd_layer{layer_num}']
                sample_data[f'layer_{layer_num}'] += [row_jsds[layer_num - 1].item() ]
                if ranked_pred:
                    sample_data_predictions[f'layer_{layer_num}'] += [f'{final_ranked}']
                else:
                    sample_data_predictions[f'layer_{layer_num}'] += [f'{layer_prediction_str}']
                

        row_counter += 1
    # print({k : len(v) for k , v in sample_data_predictions.items()})
    sample_data = pd.DataFrame(sample_data)
    sample_data.set_index('token_name', inplace=True)
    sample_data_predictions = pd.DataFrame(sample_data_predictions)
    return sample_data.transpose(), sample_data_predictions.transpose()
        



# Sample DataFrame (replace this with your actual DataFrame)

def plot_heatmap(sample_data,
                 sample_data_predictions,
                filename= None):
    # Create a heatmap
    plt.figure(figsize=(50, 9))
    sns.heatmap(sample_data, annot=False, cmap=sns.color_palette("BuPu", as_cmap=True))
    for i in range(len(sample_data.index)):
        for j in range(len(sample_data.columns)):
            plt.text(j + 0.5, i + 0.5, str(sample_data_predictions.iloc[i, j]), horizontalalignment='center', fontsize = 15, verticalalignment='center')
    plt.xticks(fontsize=18,rotation = 45)
    plt.yticks(fontsize=18)
    plt.title('Layer-wise Token Heatmap')
    plt.xlabel('Token Names')
    plt.ylabel('Layers')
    if filename:
        plt.savefig(f'{filename}.pdf')
    plt.show()
    return

# %%
#####plot difference in JSD for faithful and unfaithful tokens 
#### plot predictions by different layers 


model = 'mistral7b'
origin = 'XSUM'
tokenizer = mistral_tokenizer

df_sample_doc, nonfactual_idx_vals = get_sample_doc(model,
               origin,
               tokenizer)
# df_model_origin_nonfactual
print(nonfactual_idx_vals)
# Out:
# SUMMARY Bollywood director Sanjay Leela Bhansali to make a film on Olympics bronze medallist boxer MC Mary Koms life Kom herself the film as an inspiration to womenansali who has been planning the film for a year, impressed Mary Kom's and courage and yet decided on who will play her role The film is expected to the gap between people from the Indian mainland and those from the north-eastern states
# [29, 30]

# %%
df_sample_doc
# Out:
#      Unnamed: 0                                target_token  label  \
# 0             0  92346e3b-e994-49bd-a81d-e7175d3aaf79_10823      0
# 1             0    b522ed1c-0f84-4cee-9be7-a2a09bb73043_346      0
# 2             0   a294d73f-686b-436e-a91a-af5b34439b70_4871      0
# 3             0   a2d4ed5c-8073-4392-a8dc-ab6ec80f0a6a_6859      0
# 4             0   f38b147c-67d1-4753-940a-5d3eaf42f7ec_3652      0
# ..          ...                                         ...    ...
# 103           0   44099d62-bc63-4041-8123-ba6f678effdb_6120      0
# 104           0  9cfaf3f7-c842-446e-9d23-ef3ab1509104_28733      0
# 105           0  ad1d28e7-d9e3-4a8f-a574-1247edc030df_28706      0
# 106           0  52072450-90e3-4aee-82a2-607c9a2663fa_10230      0
# 107           0   18ab71ae-8b3e-4b88-b2f8-a78e784a4af8_4605      0
#
#      prev_hidden_state_sim_layer1  prev_hidden_state_sim_layer2  \
# 0                        0.571613                      0.716998
# 1                        0.632406                      0.818875
# 2                        0.365882                      0.640151
# 3                        0.734975                      0.540056
# 4                        0.691200                      0.831951
# ..                            ...                           ...
# 103                      0.347681                      0.774266
# 104                      0.665519                      0.867183
# 105                      0.557982                      0.721312
# 106                      0.486953                      0.717862
# 107                      0.629939                      0.669709
#
#      prev_hidden_state_sim_layer3  prev_hidden_state_sim_layer4  \
# 0                        0.773641                      0.783539
# 1                        0.831130                      0.885798
# 2                        0.765453                      0.837453
# 3                        0.804692                      0.855663
# 4                        0.790813                      0.847683
# ..                            ...                           ...
# 103                      0.870727                      0.863676
# 104                      0.799656                      0.887044
# 105                      0.774510                      0.916069
# 106                      0.778858                      0.855577
# 107                      0.781961                      0.873075
#
#      prev_hidden_state_sim_layer5  prev_hidden_state_sim_layer6  \
# 0                        0.897570                      0.868688
# 1                        0.907975                      0.924197
# 2                        0.896797                      0.904630
# 3                        0.915697                      0.904315
# 4                        0.902268                      0.887685
# ..                            ...                           ...
# 103                      0.920932                      0.898157
# 104                      0.864485                      0.910675
# 105                      0.889805                      0.921615
# 106                      0.829645                      0.855669
# 107                      0.790245                      0.897640
#
#      prev_hidden_state_sim_layer7  ...  entropy_layer32  pred_prob_layer32  \
# 0                        0.884355  ...         2.040002           0.352867
# 1                        0.899672  ...         0.000047           0.999997
# 2                        0.915212  ...         0.000788           0.999931
# 3                        0.906244  ...         0.202970           0.964888
# 4                        0.890043  ...         0.039041           0.995023
# ..                            ...  ...              ...                ...
# 103                      0.912671  ...         0.420917           0.868697
# 104                      0.900399  ...         0.007610           0.999199
# 105                      0.877440  ...         0.008545           0.998998
# 106                      0.856266  ...         0.000108           0.999992
# 107                      0.869062  ...         0.024681           0.996905
#
#      pred_token_layer32  target_prob_layer32  \
# 0                 10823             0.352867
# 1                   346             0.999997
# 2                  4871             0.999931
# 3                  6859             0.964888
# 4                  3652             0.995023
# ..                  ...                  ...
# 103                6120             0.868697
# 104               28733             0.999199
# 105               28706             0.998998
# 106               10230             0.999992
# 107                4605             0.996905
#
#                           top3_predicted_probs_layer32  \
# 0    [0.35286739468574524, 0.2680160701274872, 0.12...
# 1    [0.9999969005584717, 1.9940828224207507e-06, 5...
# 2    [0.9999309778213501, 5.7942910643760115e-05, 7...
# 3    [0.9648875594139099, 0.019548581913113594, 0.0...
# 4    [0.9950234889984131, 0.003187327180057764, 0.0...
# ..                                                 ...
# 103  [0.8686965107917786, 0.12607116997241974, 0.00...
# 104  [0.9991994500160217, 0.00044292776146903634, 0...
# 105  [0.99899822473526, 0.0008496522787027061, 8.58...
# 106  [0.9999922513961792, 5.9999010773026384e-06, 5...
# 107  [0.9969053864479065, 0.0019493874860927463, 0....
#
#      top3_predicted_tokens_layer32  \
# 0             [10823, 6735, 10598]
# 1                  [346, 2, 28724]
# 2                   [4871, 2, 809]
# 3               [6859, 2966, 9298]
# 4                 [3652, 2, 28725]
# ..                             ...
# 103            [6120, 27737, 3964]
# 104              [28733, 2, 16495]
# 105              [28706, 24294, 2]
# 106           [10230, 1993, 13827]
# 107            [4605, 4424, 10542]
#
#                                            docid  target_token_id      model  \
# 0    Cynthia Lamanda#XSUM-19389161:mistral7b-ul2            10823  mistral7b
# 1    Cynthia Lamanda#XSUM-19389161:mistral7b-ul2              346  mistral7b
# 2    Cynthia Lamanda#XSUM-19389161:mistral7b-ul2             4871  mistral7b
# 3    Cynthia Lamanda#XSUM-19389161:mistral7b-ul2             6859  mistral7b
# 4    Cynthia Lamanda#XSUM-19389161:mistral7b-ul2             3652  mistral7b
# ..                                           ...              ...        ...
# 103  Cynthia Lamanda#XSUM-19389161:mistral7b-ul2             6120  mistral7b
# 104  Cynthia Lamanda#XSUM-19389161:mistral7b-ul2            28733  mistral7b
# 105  Cynthia Lamanda#XSUM-19389161:mistral7b-ul2            28706  mistral7b
# 106  Cynthia Lamanda#XSUM-19389161:mistral7b-ul2            10230  mistral7b
# 107  Cynthia Lamanda#XSUM-19389161:mistral7b-ul2             4605  mistral7b
#
#      origin
# 0      XSUM
# 1      XSUM
# 2      XSUM
# 3      XSUM
# 4      XSUM
# ..      ...
# 103    XSUM
# 104    XSUM
# 105    XSUM
# 106    XSUM
# 107    XSUM
#
# [89 rows x 270 columns]

# %%
start_idx = 0
sample_data, sample_data_predictions= make_heatmap_plot_data(df_sample_doc,
                  start_idx = start_idx,
                  end_idx = start_idx + 30,
                  num_layers = 32,
                  ranked_pred = False)
plot_heatmap(sample_data,
             sample_data_predictions,
            filename = f'cherrypick_{origin}_{model}_pred_1')

sample_data_ranked, sample_data_predictions_ranked= make_heatmap_plot_data(df_sample_doc,
                  start_idx = start_idx,
                  end_idx = start_idx + 30,
                  num_layers = 32,
                  ranked_pred = True)
plot_heatmap(sample_data_ranked,
             sample_data_predictions_ranked,
            filename = f'cherrypick_{origin}_{model}_surfaced_1')

# df_sample_doc
# og_row = df_genaudit[df_genaudit['docid_processed'].isin(df_sample_doc['docid'])]
og_row = df_genaudit[df_genaudit['id'].isin(df_sample_doc['docid'])]
doc = og_row['source'].values[0]
summ = og_row['summary'].values[0]
print('DOCUMENT:', doc)
print('***'*13)
print('SUMMARY:', summ)
# Out:
# /tmp/ipykernel_20449/634904232.py:97: UserWarning: Glyph 21320 (\N{CJK UNIFIED IDEOGRAPH-5348}) missing from current font.
#   plt.savefig(f'{filename}.pdf')
# /tmp/ipykernel_20449/634904232.py:97: UserWarning: Glyph 59700 (\ue934) missing from current font.
#   plt.savefig(f'{filename}.pdf')
# /tmp/ipykernel_20449/634904232.py:97: UserWarning: Glyph 38500 (\N{CJK UNIFIED IDEOGRAPH-9664}) missing from current font.
#   plt.savefig(f'{filename}.pdf')
# /tmp/ipykernel_20449/634904232.py:97: UserWarning: Glyph 20303 (\N{CJK UNIFIED IDEOGRAPH-4F4F}) missing from current font.
#   plt.savefig(f'{filename}.pdf')
# /tmp/ipykernel_20449/634904232.py:97: UserWarning: Glyph 21320 (\N{CJK UNIFIED IDEOGRAPH-5348}) missing from current font.
#   plt.savefig(f'{filename}.pdf')
# /tmp/ipykernel_20449/634904232.py:97: UserWarning: Glyph 59700 (\ue934) missing from current font.
#   plt.savefig(f'{filename}.pdf')
# /tmp/ipykernel_20449/634904232.py:97: UserWarning: Glyph 38500 (\N{CJK UNIFIED IDEOGRAPH-9664}) missing from current font.
#   plt.savefig(f'{filename}.pdf')
# /tmp/ipykernel_20449/634904232.py:97: UserWarning: Glyph 20303 (\N{CJK UNIFIED IDEOGRAPH-4F4F}) missing from current font.
#   plt.savefig(f'{filename}.pdf')
# /home/ramprasad.sa/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21320 (\N{CJK UNIFIED IDEOGRAPH-5348}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ramprasad.sa/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 59700 (\ue934) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ramprasad.sa/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38500 (\N{CJK UNIFIED IDEOGRAPH-9664}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ramprasad.sa/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20303 (\N{CJK UNIFIED IDEOGRAPH-4F4F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# DOCUMENT: Indian Olympics bronze medallist, boxer MC Mary Kom, has welcomed a film that Bollywood director Sanjay Leela Bhansali wants to make on her life.. "This film will help bridge the gap between people of the Indian mainland and those from the north-eastern states," Mary Kom told the BBC.. The five-time world champion is from the remote northeast state of Manipur.. Bhansali, who has been planning the film for a year, described the boxer as an "inspiration to every Indian woman".. "I am very impressed with the way Mary Kom is leading her life with so much conviction and courage. We'll start working on the film very soon. I haven't decided on who will play her role," Bhansali told the BBC.. Recently, thousands of north-eastern people fled the Indian cities of Mumbai, Bangalore and Hyderabad fearing reprisal attacks in the wake of ethnic clashes between Bodo tribes and Muslims in the north-eastern state of Assam.. The boxer says she has been worried about her relatives and friends living in Bangalore and "could not properly sleep at night when this exodus was taking place".. The mother of twin boys feels that Bhansali's film on her will help clear the air because "our people look different but they are Indians. We have the same passions when the country is involved".. Bhansali's assistant Omung Kumar, who researched Mary Kom's life and wrote the script, will direct the film.. But will it be possible to screen the movie in the boxer's home state Manipur, where separatist rebels have imposed a ban on Bollywood films?. "I hope nobody will object to a film if it centres on my life story, my struggles to become a boxer," Mary Kom said.. India's thriving film industry has rarely picked on themes from the country's long-embattled north-eastern states and the few films that have been made have focused on the separatist insurgencies and India's counter-insurgency efforts in the region.
# ***************************************
# SUMMARY: Bollywood director Sanjay Leela Bhansali plans to make a film on Indian Olympics bronze medallist boxer MC Mary Kom's life, with Mary Kom herself describing the film as an inspiration to Indian women.. Bhansali, who has been planning the film for a year, is impressed by Mary Kom's leadership and courage, and has not yet decided on who will play her role.. The film is expected to bridge the gap between people from the Indian mainland and those from the north-eastern states.

# %%
df_genaudit[df_genaudit['id'].isin(df_sample_doc['docid'])]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, source, summary, annotated_spans, model, origin, docid_processed]
# Index: []

# %%
df_sample_doc['docid']
# Out:
# 386    REDDIT-23:llama7b-ul2
# 387    REDDIT-23:llama7b-ul2
# 389    REDDIT-23:llama7b-ul2
# 390    REDDIT-23:llama7b-ul2
# 391    REDDIT-23:llama7b-ul2
#                ...
# 467    REDDIT-23:llama7b-ul2
# 468    REDDIT-23:llama7b-ul2
# 469    REDDIT-23:llama7b-ul2
# 471    REDDIT-23:llama7b-ul2
# 472    REDDIT-23:llama7b-ul2
# Name: docid, Length: 78, dtype: object

# %%
df_genaudit['id']
# Out:
# 0            Rachel Usher#REDDIT-83:flanul2-ul2
# 1           Rachel Usher#REDDIT-83:llama70b-ul2
# 2           Rachel Usher#REDDIT-83:falcon7b-ul2
# 3            Rachel Usher#REDDIT-83:llama7b-ul2
# 4          Rachel Usher#REDDIT-83:mistral7b-ul2
#                          ...
# 697      Rachel Usher#XSUM-39387550:llama7b-ul2
# 698     Rachel Usher#XSUM-39387550:falcon7b-ul2
# 699         Rachel Usher#XSUM-39387550:gpt4-ul2
# 700    Rachel Usher#XSUM-39387550:geminipro-ul2
# 701      Rachel Usher#XSUM-39387550:chatgpt-ul2
# Name: id, Length: 702, dtype: object
