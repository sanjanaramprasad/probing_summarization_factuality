# %%
import pandas as pd

# %%
df = pd.read_csv('/home/ramprasad.sa/probing_summarization_factuality/datasets/XSUM_mistral_GPT_annotated.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                           document  \
# 0           0  The Federal Justice Office (FOJ) said the acco...
# 1           1  However, the average price is slightly down, f...
# 2           2  The incident happened during a candle-lighting...
# 3           3  The Sky Blues beat Swansea City Under-21s on p...
# 4           4  Ibrahim Halawa, 21, the son of Ireland's most ...
#
#                                              summary      model origin  \
# 0  The Federal Justice Office (FOJ) in Switzerlan...  mistral7b   XSUM
# 1  Ulster University's latest Quarterly House Pri...  mistral7b   XSUM
# 2  During a candle-lighting ceremony at Netanyahu...  mistral7b   XSUM
# 3  Coventry City beat Swansea City Under-21s on p...  mistral7b   XSUM
# 4  Ibrahim Halawa, a 21-year-old son of Ireland's...  mistral7b   XSUM
#
#   nonfactual_spans
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
nonfact_spans = list(df['nonfactual_spans'].values)

# %%
nonfact_spans
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '87 Co-op drivers in Coventry were transferred to Eddie Stobart',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'for England',
#  'Saido Berahino scored the latest goal for West Brom from a brilliant reverse pass<sep>leaving Chelsea struggling to keep up.',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'The sentence "Andrew Mitchell" does not contain any minimal inconsistent spans.<sep>There are no minimal inconsistent spans in the provided sentence.',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Jordan Clark sharing four sixes and a four with Croft in a 27-run last-wicket stand.',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'The summary incorrectly identifies Rowett as the manager of Aston Villa<sep>when the content does not specify which team he manages.',
#  nan,
#  'a report from the European Commission',
#  nan,
#  nan,
#  '33-year-old',
#  nan,
# ...
