# %%
import json
from transformers import AutoTokenizer, AutoModelForCausalLM
from pathlib import Path
import numpy as np

# %%
# Read data from JSON Lines file
def read_jsonl_file(file_path):
    data_list = []
    with open(file_path, 'r') as file:
        for line in file:
            # Parse JSON object from each line
            json_obj = json.loads(line)
            data_list.append(json_obj)

    # Print the data read from the file
    return data_list

# %%
model_path = {'mistral7b': 'mistralai/Mistral-7B-Instruct-v0.1',
             'falcon7b': 'tiiuae/falcon-7b-instruct',
             'llama7b': '/work/frink/models/Llama-2-7b-chat-hf',
             'flanul2': 'google/flan-ul2'}

def load_tokenizer(model_name):
    tokenizer = AutoTokenizer.from_pretrained(model_path[model_name],
                                         cache_dir = '/scratch/ramprasad.sa/huggingface_models')

    
    return tokenizer

# %%
import re
import string

def check_only_trailing_punctuations(token_list):
    regex = re.compile('[%s]' % re.escape(string.punctuation))
    for idx in [0, len(token_list) - 1]:
        if idx <= len(token_list) - 1:
            if not regex.sub('', token_list[idx][1]).strip():
                token_list.pop(idx)
    return token_list

def add_word_list(token_list, word_list):
    token_list = check_only_trailing_punctuations(token_list)
    if token_list:
        word_list.append(token_list)
    return word_list
    
def get_word_based_idx(summary_tokens,
                      tokenizer):
    all_words = []
    token_list = []
    for summ_tok_idx, summ_tok in enumerate(summary_tokens):
        prefix_tok_str = ''
        current_tok_str = tokenizer.decode(summ_tok)
        if summ_tok_idx > 0:
            prefix_tok_str = tokenizer.decode([summary_tokens[summ_tok_idx - 1], summ_tok])

        #### new token is start of a new word 
        if len(prefix_tok_str.split(' '))> 1:

            ### append stored tokens of a previous word
            if len(token_list) > 0:
                all_words = add_word_list(token_list, all_words)

            #### now reset token list for new word 
            token_list = [(summ_tok_idx, current_tok_str, summ_tok, )]
            
        else:
            token_list.append((summ_tok_idx, current_tok_str, summ_tok))

    all_words = add_word_list(token_list, all_words)
    return all_words



    # print(current_tok, len(word_list))
    # if len(prefix_str.split(' ')) 
    # if prev_tok is None or 
    # summ_tok_label = summary_label[summ_tok_idx]
    # summ_tok_layers_patches = summary_token_patching_results[summ_tok_idx]
    # for layer_idx, tgt_token, _, pred_token, p_clean, p_corr, p_patched in summ_tok_layers_patches:
    #     ie_score = (p_patched - p_corr) / (p_clean - p_corr)

# %%
directory_path = '/scratch/ramprasad.sa/probing_summarization_factuality/causal_analysis/noised_instruction/XSUM/mistral7b/'
directory = Path(directory_path)

# file_name = 'Rachel_Usher#XSUM-28345611:mistral7b-ul2.jsonl'
# data_list = read_jsonl_file(f'{directory}/{file_name}')

# %%
files = [file.name for file in directory.iterdir() if file.is_file()]
files_data = [read_jsonl_file(f'{directory_path}/{file}') for file in files]
# files_data[0]

# %%
tokenizer = load_tokenizer('mistral7b')
# Out:
# /home/ramprasad.sa/.conda/envs/nnsight/lib/python3.8/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
files_summary_words = []

for data_list in files_data:
    summary_tokens = [ each[0]['target'] for each in data_list]
    summary_labels = [each[0]['factual_label'] for each in data_list]
    summary_words = get_word_based_idx(summary_tokens, 
                   tokenizer)
    files_summary_words.append(summary_words)

# %%
len(files_data[0][0])
# Out:
# 32

# %%
# len(files_summary_words)
# files_summary_words[-1]\
import nltk
from nltk.corpus import stopwords

# Download NLTK stopwords data (only need to do this once)
nltk.download('stopwords')

# Get English stopwords
english_stopwords = set(stopwords.words('english'))

# Print the list of English stopwords
print(english_stopwords)
# Out:
# {'yours', 'were', 'below', "won't", 'myself', 'while', 'hers', "shouldn't", 'same', 'it', 'further', 'here', 'yourself', 'when', 'between', 'all', 're', 'just', 'don', 'your', 'being', 'he', 'my', 'to', 'both', "hasn't", 've', "doesn't", 'ourselves', "shan't", 'ain', "you're", "she's", 'with', 'those', 'weren', 'from', 'haven', 'because', 'hadn', 'was', 'should', 'll', 'they', 'that', 'have', 'who', 'isn', "wouldn't", 'her', "you've", 'had', 'do', "aren't", 'over', 'himself', 'is', "don't", 'didn', "you'll", 'as', "didn't", 'off', 'these', "wasn't", 'a', 'any', 'couldn', 'an', 'there', 'up', 'doing', 'for', 'more', "mightn't", 's', 'we', 'y', "haven't", 'some', 'o', 'its', 'she', 'having', 'above', 'through', 'you', "you'd", 'if', 'until', 'into', "should've", 'shouldn', 'not', 'than', 't', 'his', 'about', 'i', "mustn't", 'will', 'themselves', 'am', "isn't", 'yourselves', 'but', 'or', 'on', 'can', 'few', 'm', 'only', "couldn't", "that'll", 'itself', 'of', 'so', "it's", 'doesn', 'been', 'against', 'needn', 'shan', 'by', 'which', "weren't", 'their', 'under', 'mustn', 'does', 'where', 'at', 'nor', 'each', 'the', "hadn't", 'has', 'then', 'are', 'before', 'during', 'once', 'wasn', 'how', 'again', "needn't", 'won', 'why', 'now', 'out', 'mightn', 'in', 'd', 'me', 'no', 'this', 'our', 'them', 'and', 'other', 'such', 'hasn', 'theirs', 'own', 'wouldn', 'whom', 'aren', 'after', 'did', 'down', 'herself', 'be', 'ours', 'most', 'very', 'him', 'ma', 'too', 'what'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ramprasad.sa/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
files_summary_words[0][:5], len(files_data[0][10])
# Out:
# ([[(0, 'Bol', 10823), (1, 'ly', 346), (2, 'wood', 4871)],
#   [(3, 'director', 6859)],
#   [(4, 'San', 3652), (5, 'j', 28768), (6, 'ay', 339)],
#   [(7, 'Le', 1337), (8, 'ela', 4403)],
#   [(9, 'Bh', 18811), (10, 'ans', 509), (11, 'ali', 4827)]],
#  32)

# %%
import math 


def get_all_summary_words(files_data):
    files_summary_words = []

    for data_list in files_data:
        summary_tokens = [ each[0]['target'] for each in data_list]
        summary_labels = [each[0]['factual_label'] for each in data_list]
        summary_words = get_word_based_idx(summary_tokens, 
                       tokenizer)
        files_summary_words.append(summary_words)
    return files_summary_words


def get_ie_score(layerwise_result):
    predicted = layerwise_result['predicted']
    target = layerwise_result['target']
    factual_label = layerwise_result['factual_label']
    layer_num = layerwise_result['layer']
    prob_clean = layerwise_result['prob_clean']
    prob_corrupted = layerwise_result['prob_corrupted']
    prob_patched = layerwise_result['prob_patched']
                    
    if predicted == target:
        ie_score = (prob_patched - prob_corrupted) / (prob_clean - prob_corrupted)
        return ie_score
    return None


def make_df_patching(files_data):
    df_dict_patching = { f'layer_{layer_num}': [] for layer_num in range(len(files_data[0][0]))}
    df_dict_patching['token_pos'] = []
    df_dict_patching['token_factual_label'] = []

    files_summary_words = get_all_summary_words(files_data)
    #### go through all summaries in the file data
    for file_idx, summary_words in enumerate(files_summary_words):
        data_list = files_data[file_idx]
        ### for each summary word in the list of words
        for summ_word in summary_words:
            #### since each word can have many tokens, go through each token for that word
            for tok_pos, tok_info in enumerate(summ_word):
                tok_idx = tok_info[0]
                tok_layerwise_results = data_list[tok_idx]
                appended = False
                
                for layerwise_res in tok_layerwise_results:
                    
                    layer_num = layerwise_res['layer']
                    ie_score = get_ie_score(layerwise_res)
                    # print(layerwise_res)
                    if ie_score != None:
                        appended = True
                        df_dict_patching[f'layer_{layer_num}'] += [ie_score]
                        
                if appended:
                    tok_pos_str = 'middle'
                    if tok_pos ==0:
                        tok_pos_str = 'first'
                    elif tok_pos == len(summ_word) -1:
                        tok_pos_str = 'last'
                    df_dict_patching['token_pos'] += [tok_pos_str]
                    # sample_layer_res = data_list[summ_word[0][0]][0]
                    df_dict_patching['token_factual_label'] += [data_list[summ_word[0][0]][0]['factual_label']]
                    # if tok_pos_str == 'first' and data_list[summ_word[0][0]][0]['factual_label'] == 0:
                    #     print(tok_layerwise_results[24])
    return pd.DataFrame(df_dict_patching)


def get_aie_scores(df_dict_patching):
    df_dict_plot = {f'layer_{layer_num}': [] for layer_num in range(len(data_list[0]))}
    df_dict_plot['Token'] = []
    
    
    for token_pos in ['first', 'middle', 'last']:
        for factual_label in [0, 1]:
            factual_label_str = 'factual' if factual_label == 0 else 'nonfactual'
            df_dict_plot['Token'] += [f'{factual_label_str}_{token_pos}']
        
    for token_pos in ['first', 'middle', 'last']:
        for factual_label in [0, 1]:
            df_subset = df_dict_patching[(df_dict_patching['token_factual_label'] == factual_label) & \
                        (df_dict_patching['token_pos'] ==token_pos)]
            if len(df_subset) == 0:
                print(token_pos, factual_label)
                
            factual_label_str = 'factual' if factual_label == 0 else 'nonfactual'
            for layer_num in range(len(data_list[0])):
                layer_num = f'layer_{layer_num}'
                df_dict_plot[layer_num] += [np.mean(df_subset[layer_num].values) if len(df_subset) > 0 else 0]

    df_dict_plot = pd.DataFrame(df_dict_plot)
    return df_dict_plot

# %%
df_dict_patching = make_df_patching(files_data)
df_dict_patching = get_aie_scores(df_dict_patching)
df_dict_patching
# Out:
# {'layer': 24, 'target': 6859, 'predicted': 6859, 'factual_label': 0, 'prob_clean': 0.9227554202079773, 'prob_corrupted': 5.250403319223551e-06, 'prob_patched': 0.8940770030021667}
# {'layer': 24, 'target': 3652, 'predicted': 3652, 'factual_label': 0, 'prob_clean': 0.9964242577552795, 'prob_corrupted': 0.000152478416566737, 'prob_patched': 0.9922467470169067}
# {'layer': 24, 'target': 1337, 'predicted': 1337, 'factual_label': 0, 'prob_clean': 0.9964101910591125, 'prob_corrupted': 6.70010713577085e-09, 'prob_patched': 0.9899778366088867}
# {'layer': 24, 'target': 18811, 'predicted': 18811, 'factual_label': 0, 'prob_clean': 0.9999417066574097, 'prob_corrupted': 7.178746486147247e-11, 'prob_patched': 0.9996795654296875}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.9806025624275208, 'prob_corrupted': 0.027150833979249, 'prob_patched': 0.965272068977356}
# {'layer': 24, 'target': 1038, 'predicted': 1038, 'factual_label': 0, 'prob_clean': 0.8767474889755249, 'prob_corrupted': 0.0001663877919781953, 'prob_patched': 0.8959229588508606}
# {'layer': 24, 'target': 264, 'predicted': 264, 'factual_label': 0, 'prob_clean': 0.9994807839393616, 'prob_corrupted': 0.000186767298146151, 'prob_patched': 0.9977895021438599}
# {'layer': 24, 'target': 2966, 'predicted': 2966, 'factual_label': 0, 'prob_clean': 0.9918453097343445, 'prob_corrupted': 0.0005131891230121255, 'prob_patched': 0.9820138812065125}
# {'layer': 24, 'target': 356, 'predicted': 356, 'factual_label': 0, 'prob_clean': 0.5081380009651184, 'prob_corrupted': 2.290732845722232e-05, 'prob_patched': 0.5870359539985657}
# {'layer': 24, 'target': 21351, 'predicted': 21351, 'factual_label': 0, 'prob_clean': 0.5546566247940063, 'prob_corrupted': 5.436672654468566e-05, 'prob_patched': 0.574918270111084}
# {'layer': 24, 'target': 20067, 'predicted': 20067, 'factual_label': 0, 'prob_clean': 0.9343920946121216, 'prob_corrupted': 9.539685561321676e-05, 'prob_patched': 0.9463403820991516}
# {'layer': 24, 'target': 1342, 'predicted': 1342, 'factual_label': 0, 'prob_clean': 0.9634467959403992, 'prob_corrupted': 0.0010710670612752438, 'prob_patched': 0.9703866243362427}
# {'layer': 24, 'target': 3890, 'predicted': 3890, 'factual_label': 0, 'prob_clean': 0.3085922300815582, 'prob_corrupted': 2.513641561563418e-07, 'prob_patched': 0.2507072687149048}
# {'layer': 24, 'target': 16416, 'predicted': 16416, 'factual_label': 0, 'prob_clean': 0.9391089081764221, 'prob_corrupted': 6.422111709980527e-06, 'prob_patched': 0.9142407774925232}
# {'layer': 24, 'target': 5480, 'predicted': 5480, 'factual_label': 0, 'prob_clean': 0.9999408721923828, 'prob_corrupted': 0.18735013902187347, 'prob_patched': 0.9996711015701294}
# {'layer': 24, 'target': 9227, 'predicted': 9227, 'factual_label': 0, 'prob_clean': 0.9998327493667603, 'prob_corrupted': 6.993239367147908e-06, 'prob_patched': 0.9995974898338318}
# {'layer': 24, 'target': 1411, 'predicted': 1411, 'factual_label': 0, 'prob_clean': 0.9996815919876099, 'prob_corrupted': 6.538320462823322e-07, 'prob_patched': 0.9991581439971924}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.8141100406646729, 'prob_corrupted': 0.0007257370161823928, 'prob_patched': 0.7741130590438843}
# {'layer': 24, 'target': 2966, 'predicted': 2966, 'factual_label': 0, 'prob_clean': 0.8946593403816223, 'prob_corrupted': 7.0615453296341e-05, 'prob_patched': 0.8450685739517212}
# {'layer': 24, 'target': 390, 'predicted': 390, 'factual_label': 0, 'prob_clean': 0.9677780270576477, 'prob_corrupted': 4.372851617517881e-05, 'prob_patched': 0.9564194679260254}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.4390996992588043, 'prob_corrupted': 1.8532504327595234e-05, 'prob_patched': 0.4255293905735016}
# {'layer': 24, 'target': 693, 'predicted': 693, 'factual_label': 0, 'prob_clean': 0.31013426184654236, 'prob_corrupted': 0.00020593166118487716, 'prob_patched': 0.23514071106910706}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.7869643568992615, 'prob_corrupted': 0.004258864559233189, 'prob_patched': 0.8285982608795166}
# {'layer': 24, 'target': 2966, 'predicted': 2966, 'factual_label': 0, 'prob_clean': 0.6847849488258362, 'prob_corrupted': 4.112463284400292e-05, 'prob_patched': 0.7013543248176575}
# {'layer': 24, 'target': 354, 'predicted': 354, 'factual_label': 0, 'prob_clean': 0.936201274394989, 'prob_corrupted': 8.92299703991739e-06, 'prob_patched': 0.934284508228302}
# {'layer': 24, 'target': 486, 'predicted': 486, 'factual_label': 0, 'prob_clean': 0.7171916365623474, 'prob_corrupted': 2.860341191990301e-05, 'prob_patched': 0.7434025406837463}
# {'layer': 24, 'target': 5480, 'predicted': 5480, 'factual_label': 0, 'prob_clean': 0.7638081908226013, 'prob_corrupted': 0.00016452354611828923, 'prob_patched': 0.6552078723907471}
# {'layer': 24, 'target': 9227, 'predicted': 9227, 'factual_label': 0, 'prob_clean': 0.9954710006713867, 'prob_corrupted': 0.2010355293750763, 'prob_patched': 0.9988304972648621}
# {'layer': 24, 'target': 304, 'predicted': 304, 'factual_label': 0, 'prob_clean': 0.3228186070919037, 'prob_corrupted': 0.00013916270108893514, 'prob_patched': 0.3123960494995117}
# {'layer': 24, 'target': 304, 'predicted': 304, 'factual_label': 0, 'prob_clean': 0.5964462757110596, 'prob_corrupted': 0.06483842432498932, 'prob_patched': 0.47351697087287903}
# {'layer': 24, 'target': 2783, 'predicted': 2783, 'factual_label': 0, 'prob_clean': 0.35193392634391785, 'prob_corrupted': 0.0002562861773185432, 'prob_patched': 0.33773311972618103}
# {'layer': 24, 'target': 4496, 'predicted': 4496, 'factual_label': 0, 'prob_clean': 0.39035677909851074, 'prob_corrupted': 0.015023996122181416, 'prob_patched': 0.4358842968940735}
# {'layer': 24, 'target': 356, 'predicted': 356, 'factual_label': 0, 'prob_clean': 0.8526387810707092, 'prob_corrupted': 2.6094123313669115e-05, 'prob_patched': 0.8823060989379883}
# {'layer': 24, 'target': 622, 'predicted': 622, 'factual_label': 0, 'prob_clean': 0.9585245251655579, 'prob_corrupted': 1.2819812127418118e-06, 'prob_patched': 0.9721615314483643}
# {'layer': 24, 'target': 1156, 'predicted': 1156, 'factual_label': 0, 'prob_clean': 0.8340107202529907, 'prob_corrupted': 1.6826790670165792e-05, 'prob_patched': 0.774321436882019}
# {'layer': 24, 'target': 415, 'predicted': 415, 'factual_label': 0, 'prob_clean': 0.5383108258247375, 'prob_corrupted': 1.0817783731909003e-05, 'prob_patched': 0.513849675655365}
# {'layer': 24, 'target': 2966, 'predicted': 2966, 'factual_label': 0, 'prob_clean': 0.9288246035575867, 'prob_corrupted': 4.195417568553239e-05, 'prob_patched': 0.9187881946563721}
# {'layer': 24, 'target': 349, 'predicted': 349, 'factual_label': 0, 'prob_clean': 0.3992418646812439, 'prob_corrupted': 1.760619124979712e-05, 'prob_patched': 0.43240979313850403}
# {'layer': 24, 'target': 3349, 'predicted': 3349, 'factual_label': 0, 'prob_clean': 0.7035650014877319, 'prob_corrupted': 2.1516923879971728e-05, 'prob_patched': 0.6643499732017517}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.9986214637756348, 'prob_corrupted': 0.006924686953425407, 'prob_patched': 0.9984391331672668}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.9839426279067993, 'prob_corrupted': 8.469438034808263e-05, 'prob_patched': 0.9862602353096008}
# {'layer': 24, 'target': 10467, 'predicted': 10467, 'factual_label': 0, 'prob_clean': 0.9845609664916992, 'prob_corrupted': 1.9519031411618926e-05, 'prob_patched': 0.9792147874832153}
# {'layer': 24, 'target': 1444, 'predicted': 1444, 'factual_label': 0, 'prob_clean': 0.9990645051002502, 'prob_corrupted': 4.263540631654905e-06, 'prob_patched': 0.9991992115974426}
# {'layer': 24, 'target': 905, 'predicted': 905, 'factual_label': 0, 'prob_clean': 0.7054352164268494, 'prob_corrupted': 5.70666634303052e-06, 'prob_patched': 0.6989163756370544}
# {'layer': 24, 'target': 477, 'predicted': 477, 'factual_label': 0, 'prob_clean': 0.4806162714958191, 'prob_corrupted': 4.261549122475117e-07, 'prob_patched': 0.49433791637420654}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.8317213654518127, 'prob_corrupted': 1.6161326129804365e-05, 'prob_patched': 0.7983469367027283}
# {'layer': 24, 'target': 6735, 'predicted': 6735, 'factual_label': 0, 'prob_clean': 0.8303158283233643, 'prob_corrupted': 0.005923639051616192, 'prob_patched': 0.8482009172439575}
# {'layer': 24, 'target': 2191, 'predicted': 2191, 'factual_label': 0, 'prob_clean': 0.9984664916992188, 'prob_corrupted': 0.16507425904273987, 'prob_patched': 0.998461127281189}
# {'layer': 24, 'target': 304, 'predicted': 304, 'factual_label': 0, 'prob_clean': 0.9992677569389343, 'prob_corrupted': 6.942324262126931e-07, 'prob_patched': 0.9991853833198547}
# {'layer': 24, 'target': 1395, 'predicted': 1395, 'factual_label': 0, 'prob_clean': 0.7614904642105103, 'prob_corrupted': 7.155458092711342e-08, 'prob_patched': 0.7763432860374451}
# {'layer': 24, 'target': 477, 'predicted': 477, 'factual_label': 0, 'prob_clean': 0.9860919117927551, 'prob_corrupted': 0.0015585196670144796, 'prob_patched': 0.9778079986572266}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.9090886116027832, 'prob_corrupted': 8.578548658988439e-06, 'prob_patched': 0.9119535088539124}
# {'layer': 24, 'target': 6120, 'predicted': 6120, 'factual_label': 0, 'prob_clean': 0.9223933815956116, 'prob_corrupted': 0.021867988631129265, 'prob_patched': 0.9283668994903564}
# {'layer': 24, 'target': 4605, 'predicted': 4605, 'factual_label': 0, 'prob_clean': 0.9833268523216248, 'prob_corrupted': 1.0523347748758738e-09, 'prob_patched': 0.9878308176994324}
# {'layer': 24, 'target': 5470, 'predicted': 5470, 'factual_label': 0, 'prob_clean': 0.9483225345611572, 'prob_corrupted': 0.0028291286434978247, 'prob_patched': 0.8416538834571838}
# {'layer': 24, 'target': 659, 'predicted': 659, 'factual_label': 0, 'prob_clean': 0.7365317940711975, 'prob_corrupted': 5.7426154853601474e-06, 'prob_patched': 0.6078459024429321}
# {'layer': 24, 'target': 7004, 'predicted': 7004, 'factual_label': 0, 'prob_clean': 0.9472174644470215, 'prob_corrupted': 0.0303670484572649, 'prob_patched': 0.9073328375816345}
# {'layer': 24, 'target': 396, 'predicted': 396, 'factual_label': 0, 'prob_clean': 0.725621223449707, 'prob_corrupted': 0.0004429044493008405, 'prob_patched': 0.6312308311462402}
# {'layer': 24, 'target': 544, 'predicted': 544, 'factual_label': 0, 'prob_clean': 0.996127188205719, 'prob_corrupted': 0.003985409624874592, 'prob_patched': 0.9885304570198059}
# {'layer': 24, 'target': 1407, 'predicted': 1407, 'factual_label': 0, 'prob_clean': 0.9980522394180298, 'prob_corrupted': 2.0738721104862634e-06, 'prob_patched': 0.9892701506614685}
# {'layer': 24, 'target': 354, 'predicted': 354, 'factual_label': 0, 'prob_clean': 0.9167203307151794, 'prob_corrupted': 2.5833907102423836e-07, 'prob_patched': 0.8229084610939026}
# {'layer': 24, 'target': 871, 'predicted': 871, 'factual_label': 0, 'prob_clean': 0.8149221539497375, 'prob_corrupted': 0.00021239188208710402, 'prob_patched': 0.6473841071128845}
# {'layer': 24, 'target': 8333, 'predicted': 8333, 'factual_label': 0, 'prob_clean': 0.9955667853355408, 'prob_corrupted': 5.0280581490369514e-05, 'prob_patched': 0.9853394031524658}
# {'layer': 24, 'target': 302, 'predicted': 302, 'factual_label': 0, 'prob_clean': 0.9980456829071045, 'prob_corrupted': 1.7825306713348255e-05, 'prob_patched': 0.9925948977470398}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.6066439151763916, 'prob_corrupted': 0.00010840423055924475, 'prob_patched': 0.5342987775802612}
# {'layer': 24, 'target': 1691, 'predicted': 1691, 'factual_label': 0, 'prob_clean': 0.7887681722640991, 'prob_corrupted': 0.03777235001325607, 'prob_patched': 0.7725592255592346}
# {'layer': 24, 'target': 302, 'predicted': 302, 'factual_label': 0, 'prob_clean': 0.9993127584457397, 'prob_corrupted': 3.3500457963242525e-09, 'prob_patched': 0.9967764019966125}
# {'layer': 24, 'target': 394, 'predicted': 394, 'factual_label': 0, 'prob_clean': 0.9991852641105652, 'prob_corrupted': 7.27145061318879e-06, 'prob_patched': 0.9978784322738647}
# {'layer': 24, 'target': 1951, 'predicted': 1951, 'factual_label': 0, 'prob_clean': 0.7003665566444397, 'prob_corrupted': 7.503390131446963e-10, 'prob_patched': 0.6037781238555908}
# {'layer': 24, 'target': 415, 'predicted': 415, 'factual_label': 0, 'prob_clean': 0.678648829460144, 'prob_corrupted': 0.00018507799541112036, 'prob_patched': 0.672304093837738}
# {'layer': 24, 'target': 690, 'predicted': 690, 'factual_label': 0, 'prob_clean': 0.7963592410087585, 'prob_corrupted': 0.00014138277038000524, 'prob_patched': 0.6507766246795654}
# {'layer': 24, 'target': 4347, 'predicted': 4347, 'factual_label': 0, 'prob_clean': 0.27357053756713867, 'prob_corrupted': 5.5573127610841766e-05, 'prob_patched': 0.2507596015930176}
# {'layer': 24, 'target': 1633, 'predicted': 1633, 'factual_label': 0, 'prob_clean': 0.9975283741950989, 'prob_corrupted': 6.528721314680297e-07, 'prob_patched': 0.9955724477767944}
# {'layer': 24, 'target': 18486, 'predicted': 18486, 'factual_label': 0, 'prob_clean': 0.7157027721405029, 'prob_corrupted': 4.5200604148476486e-08, 'prob_patched': 0.6177698969841003}
# {'layer': 24, 'target': 7442, 'predicted': 7442, 'factual_label': 0, 'prob_clean': 0.9922618865966797, 'prob_corrupted': 0.00014927847951184958, 'prob_patched': 0.9844271540641785}
# {'layer': 24, 'target': 4120, 'predicted': 4120, 'factual_label': 0, 'prob_clean': 0.986814022064209, 'prob_corrupted': 0.5511285066604614, 'prob_patched': 0.9934819340705872}
# {'layer': 24, 'target': 622, 'predicted': 622, 'factual_label': 0, 'prob_clean': 0.6061525344848633, 'prob_corrupted': 0.00031176250195130706, 'prob_patched': 0.5738755464553833}
# {'layer': 24, 'target': 4480, 'predicted': 4480, 'factual_label': 0, 'prob_clean': 0.9249994158744812, 'prob_corrupted': 0.0001327362551819533, 'prob_patched': 0.9103190302848816}
# {'layer': 24, 'target': 1259, 'predicted': 1259, 'factual_label': 0, 'prob_clean': 0.4133625626564026, 'prob_corrupted': 1.788925771961658e-07, 'prob_patched': 0.36462363600730896}
# {'layer': 24, 'target': 390, 'predicted': 390, 'factual_label': 0, 'prob_clean': 0.9989066123962402, 'prob_corrupted': 0.001821273472160101, 'prob_patched': 0.9972825050354004}
# {'layer': 24, 'target': 4348, 'predicted': 4348, 'factual_label': 0, 'prob_clean': 0.9961613416671753, 'prob_corrupted': 0.0008534807711839676, 'prob_patched': 0.9888416528701782}
# {'layer': 24, 'target': 1500, 'predicted': 1500, 'factual_label': 0, 'prob_clean': 0.9997730851173401, 'prob_corrupted': 2.53299589303424e-07, 'prob_patched': 0.9991525411605835}
# {'layer': 24, 'target': 7205, 'predicted': 7205, 'factual_label': 0, 'prob_clean': 0.9985933899879456, 'prob_corrupted': 0.0001812325936043635, 'prob_patched': 0.9966283440589905}
# {'layer': 24, 'target': 413, 'predicted': 413, 'factual_label': 0, 'prob_clean': 0.9981521964073181, 'prob_corrupted': 8.16523471058872e-09, 'prob_patched': 0.9964202642440796}
# {'layer': 24, 'target': 304, 'predicted': 304, 'factual_label': 0, 'prob_clean': 0.5760164856910706, 'prob_corrupted': 2.9113222943522032e-09, 'prob_patched': 0.668237030506134}
# {'layer': 24, 'target': 393, 'predicted': 393, 'factual_label': 0, 'prob_clean': 0.9983283877372742, 'prob_corrupted': 9.326026884082239e-06, 'prob_patched': 0.9963032007217407}
# {'layer': 24, 'target': 1700, 'predicted': 1700, 'factual_label': 0, 'prob_clean': 0.9985901713371277, 'prob_corrupted': 2.9065953199847172e-08, 'prob_patched': 0.9953983426094055}
# {'layer': 24, 'target': 23780, 'predicted': 23780, 'factual_label': 0, 'prob_clean': 0.9997594952583313, 'prob_corrupted': 0.0001420394837623462, 'prob_patched': 0.9992732405662537}
# {'layer': 24, 'target': 13291, 'predicted': 13291, 'factual_label': 0, 'prob_clean': 0.37357231974601746, 'prob_corrupted': 0.06097859516739845, 'prob_patched': 0.32665884494781494}
# {'layer': 24, 'target': 11900, 'predicted': 11900, 'factual_label': 0, 'prob_clean': 0.5559141039848328, 'prob_corrupted': 0.022224554792046547, 'prob_patched': 0.4932575821876526}
# {'layer': 24, 'target': 2490, 'predicted': 2490, 'factual_label': 0, 'prob_clean': 0.2963653802871704, 'prob_corrupted': 7.325775641220389e-06, 'prob_patched': 0.28876516222953796}
# {'layer': 24, 'target': 415, 'predicted': 415, 'factual_label': 0, 'prob_clean': 0.9912746548652649, 'prob_corrupted': 0.1310977339744568, 'prob_patched': 0.9822604060173035}
# {'layer': 24, 'target': 18199, 'predicted': 18199, 'factual_label': 0, 'prob_clean': 0.9995098114013672, 'prob_corrupted': 0.00027204834623262286, 'prob_patched': 0.9992114305496216}
# {'layer': 24, 'target': 22793, 'predicted': 22793, 'factual_label': 0, 'prob_clean': 0.9977366924285889, 'prob_corrupted': 5.4626960732662155e-09, 'prob_patched': 0.9952062964439392}
# {'layer': 24, 'target': 304, 'predicted': 304, 'factual_label': 0, 'prob_clean': 0.9854236245155334, 'prob_corrupted': 4.777671165356878e-07, 'prob_patched': 0.9789760708808899}
# {'layer': 24, 'target': 6605, 'predicted': 6605, 'factual_label': 0, 'prob_clean': 0.9992934465408325, 'prob_corrupted': 8.18160242488375e-06, 'prob_patched': 0.9984877109527588}
# {'layer': 24, 'target': 415, 'predicted': 415, 'factual_label': 0, 'prob_clean': 0.48166537284851074, 'prob_corrupted': 2.8810703952331096e-05, 'prob_patched': 0.44552624225616455}
# {'layer': 24, 'target': 20990, 'predicted': 20990, 'factual_label': 0, 'prob_clean': 0.38813313841819763, 'prob_corrupted': 1.3590271237262641e-06, 'prob_patched': 0.3916878402233124}
# {'layer': 24, 'target': 3435, 'predicted': 3435, 'factual_label': 0, 'prob_clean': 0.5553635954856873, 'prob_corrupted': 1.2022783266729675e-06, 'prob_patched': 0.5176902413368225}
# {'layer': 24, 'target': 1024, 'predicted': 1024, 'factual_label': 0, 'prob_clean': 0.6008433103561401, 'prob_corrupted': 8.035131941142026e-06, 'prob_patched': 0.5645686984062195}
# {'layer': 24, 'target': 17584, 'predicted': 17584, 'factual_label': 0, 'prob_clean': 0.4007234573364258, 'prob_corrupted': 2.634727707118145e-06, 'prob_patched': 0.4135819375514984}
# {'layer': 24, 'target': 302, 'predicted': 302, 'factual_label': 0, 'prob_clean': 0.6176759004592896, 'prob_corrupted': 1.1922646081075072e-05, 'prob_patched': 0.5544438362121582}
# {'layer': 24, 'target': 799, 'predicted': 799, 'factual_label': 0, 'prob_clean': 0.9167142510414124, 'prob_corrupted': 0.0003627078258432448, 'prob_patched': 0.7384435534477234}
# {'layer': 24, 'target': 12649, 'predicted': 12649, 'factual_label': 0, 'prob_clean': 0.9956106543540955, 'prob_corrupted': 0.07947500795125961, 'prob_patched': 0.994753360748291}
# {'layer': 24, 'target': 354, 'predicted': 354, 'factual_label': 0, 'prob_clean': 0.9814438819885254, 'prob_corrupted': 2.5382687271480187e-11, 'prob_patched': 0.9581507444381714}
# {'layer': 24, 'target': 5502, 'predicted': 5502, 'factual_label': 0, 'prob_clean': 0.7985956072807312, 'prob_corrupted': 0.0042793541215360165, 'prob_patched': 0.7438932061195374}
# {'layer': 24, 'target': 302, 'predicted': 302, 'factual_label': 0, 'prob_clean': 0.9987449645996094, 'prob_corrupted': 5.32270360054099e-06, 'prob_patched': 0.9982105493545532}
# {'layer': 24, 'target': 2525, 'predicted': 2525, 'factual_label': 0, 'prob_clean': 0.7855978012084961, 'prob_corrupted': 2.5548793928464875e-05, 'prob_patched': 0.7961950302124023}
# {'layer': 24, 'target': 356, 'predicted': 356, 'factual_label': 0, 'prob_clean': 0.9618064165115356, 'prob_corrupted': 2.281100478285225e-06, 'prob_patched': 0.9551378488540649}
# {'layer': 24, 'target': 652, 'predicted': 652, 'factual_label': 0, 'prob_clean': 0.9993317723274231, 'prob_corrupted': 6.741917331964942e-06, 'prob_patched': 0.9989946484565735}
# {'layer': 24, 'target': 16843, 'predicted': 16843, 'factual_label': 0, 'prob_clean': 0.8389868140220642, 'prob_corrupted': 4.782363248523325e-05, 'prob_patched': 0.815887451171875}
# {'layer': 24, 'target': 879, 'predicted': 879, 'factual_label': 0, 'prob_clean': 0.9992758631706238, 'prob_corrupted': 1.4013707186677493e-05, 'prob_patched': 0.9983261227607727}
# {'layer': 24, 'target': 349, 'predicted': 349, 'factual_label': 0, 'prob_clean': 0.9923111200332642, 'prob_corrupted': 1.4649061995442025e-05, 'prob_patched': 0.9826175570487976}
# {'layer': 24, 'target': 302, 'predicted': 302, 'factual_label': 0, 'prob_clean': 0.8880048394203186, 'prob_corrupted': 2.4546097847633064e-05, 'prob_patched': 0.8328871726989746}
# {'layer': 24, 'target': 7481, 'predicted': 7481, 'factual_label': 0, 'prob_clean': 0.9741007685661316, 'prob_corrupted': 0.0021459164563566446, 'prob_patched': 0.8476507663726807}
# {'layer': 24, 'target': 622, 'predicted': 622, 'factual_label': 0, 'prob_clean': 0.8366168141365051, 'prob_corrupted': 0.13322579860687256, 'prob_patched': 0.8240277171134949}
# {'layer': 24, 'target': 347, 'predicted': 347, 'factual_label': 0, 'prob_clean': 0.9717722535133362, 'prob_corrupted': 3.424335227464326e-05, 'prob_patched': 0.9722902178764343}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.6658761501312256, 'prob_corrupted': 0.00011083031859016046, 'prob_patched': 0.7035947442054749}
# {'layer': 24, 'target': 14416, 'predicted': 14416, 'factual_label': 0, 'prob_clean': 0.8671583533287048, 'prob_corrupted': 4.758583236252889e-05, 'prob_patched': 0.7776160836219788}
# {'layer': 24, 'target': 3024, 'predicted': 3024, 'factual_label': 0, 'prob_clean': 0.9344058632850647, 'prob_corrupted': 7.312011121030082e-07, 'prob_patched': 0.9368471503257751}
# {'layer': 24, 'target': 12913, 'predicted': 12913, 'factual_label': 0, 'prob_clean': 0.999825656414032, 'prob_corrupted': 5.421574087449699e-07, 'prob_patched': 0.9992688298225403}
# {'layer': 24, 'target': 304, 'predicted': 304, 'factual_label': 0, 'prob_clean': 0.6484261751174927, 'prob_corrupted': 1.8313119653612375e-05, 'prob_patched': 0.6795809268951416}
# {'layer': 24, 'target': 28740, 'predicted': 28740, 'factual_label': 0, 'prob_clean': 0.946672260761261, 'prob_corrupted': 0.00013958178169559687, 'prob_patched': 0.8688610792160034}
# {'layer': 24, 'target': 10699, 'predicted': 10699, 'factual_label': 0, 'prob_clean': 0.4560096263885498, 'prob_corrupted': 6.727918662363663e-05, 'prob_patched': 0.22162552177906036}
# {'layer': 24, 'target': 11821, 'predicted': 11821, 'factual_label': 0, 'prob_clean': 0.9733259677886963, 'prob_corrupted': 5.738976369684679e-07, 'prob_patched': 0.9324239492416382}
# {'layer': 24, 'target': 25963, 'predicted': 25963, 'factual_label': 0, 'prob_clean': 0.9992302656173706, 'prob_corrupted': 0.000765798264183104, 'prob_patched': 0.9962974190711975}
# {'layer': 24, 'target': 264, 'predicted': 264, 'factual_label': 0, 'prob_clean': 0.5358229279518127, 'prob_corrupted': 5.592732486547902e-05, 'prob_patched': 0.484706848859787}
# {'layer': 24, 'target': 5864, 'predicted': 5864, 'factual_label': 0, 'prob_clean': 0.8595883250236511, 'prob_corrupted': 0.03839510679244995, 'prob_patched': 0.39875268936157227}
# {'layer': 24, 'target': 11817, 'predicted': 11817, 'factual_label': 0, 'prob_clean': 0.7415149211883545, 'prob_corrupted': 0.016830459237098694, 'prob_patched': 0.7058933973312378}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.7926486730575562, 'prob_corrupted': 2.03895633603679e-05, 'prob_patched': 0.7400299310684204}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.9755150675773621, 'prob_corrupted': 5.9421876358101144e-05, 'prob_patched': 0.9500199556350708}
# {'layer': 24, 'target': 8725, 'predicted': 8725, 'factual_label': 0, 'prob_clean': 0.6828123331069946, 'prob_corrupted': 0.0002727717801462859, 'prob_patched': 0.5148959159851074}
# {'layer': 24, 'target': 297, 'predicted': 297, 'factual_label': 0, 'prob_clean': 0.4597540497779846, 'prob_corrupted': 1.8904996977653354e-05, 'prob_patched': 0.5250118374824524}
# {'layer': 24, 'target': 28750, 'predicted': 28750, 'factual_label': 0, 'prob_clean': 0.999970555305481, 'prob_corrupted': 3.150892007397488e-05, 'prob_patched': 0.40100181102752686}
# {'layer': 24, 'target': 8737, 'predicted': 8737, 'factual_label': 0, 'prob_clean': 0.5289971828460693, 'prob_corrupted': 1.857926145021338e-05, 'prob_patched': 0.12786488234996796}
# {'layer': 24, 'target': 1863, 'predicted': 1863, 'factual_label': 0, 'prob_clean': 0.9247747659683228, 'prob_corrupted': 0.03691008687019348, 'prob_patched': 0.8789199590682983}
# {'layer': 24, 'target': 6305, 'predicted': 6305, 'factual_label': 0, 'prob_clean': 0.869016706943512, 'prob_corrupted': 0.0319603867828846, 'prob_patched': 0.9236222505569458}
# {'layer': 24, 'target': 5247, 'predicted': 5247, 'factual_label': 0, 'prob_clean': 0.9529582858085632, 'prob_corrupted': 0.00016024761134758592, 'prob_patched': 0.8807364702224731}
# {'layer': 24, 'target': 302, 'predicted': 302, 'factual_label': 0, 'prob_clean': 0.8039323687553406, 'prob_corrupted': 8.021482244657818e-06, 'prob_patched': 0.778729259967804}
# {'layer': 24, 'target': 28781, 'predicted': 28781, 'factual_label': 0, 'prob_clean': 0.9994674324989319, 'prob_corrupted': 1.338443598797312e-05, 'prob_patched': 0.9957751631736755}
# {'layer': 24, 'target': 477, 'predicted': 477, 'factual_label': 0, 'prob_clean': 0.8042153716087341, 'prob_corrupted': 2.983300873893313e-05, 'prob_patched': 0.681074321269989}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.992824912071228, 'prob_corrupted': 3.5525616112863645e-05, 'prob_patched': 0.9881964325904846}
# {'layer': 24, 'target': 3454, 'predicted': 3454, 'factual_label': 0, 'prob_clean': 0.9867401719093323, 'prob_corrupted': 0.004926764871925116, 'prob_patched': 0.9840670824050903}
# {'layer': 24, 'target': 879, 'predicted': 879, 'factual_label': 0, 'prob_clean': 0.9991980195045471, 'prob_corrupted': 0.009512710385024548, 'prob_patched': 0.9988941550254822}
# {'layer': 24, 'target': 456, 'predicted': 456, 'factual_label': 0, 'prob_clean': 0.8003596067428589, 'prob_corrupted': 5.328462066245265e-05, 'prob_patched': 0.7096173167228699}
# {'layer': 24, 'target': 403, 'predicted': 403, 'factual_label': 0, 'prob_clean': 0.6135327219963074, 'prob_corrupted': 6.765766011085361e-05, 'prob_patched': 0.568494439125061}
# {'layer': 24, 'target': 25764, 'predicted': 25764, 'factual_label': 0, 'prob_clean': 0.9537171721458435, 'prob_corrupted': 0.0002716756716836244, 'prob_patched': 0.9090143442153931}
# {'layer': 24, 'target': 297, 'predicted': 297, 'factual_label': 0, 'prob_clean': 0.8162805438041687, 'prob_corrupted': 0.019808320328593254, 'prob_patched': 0.7881838083267212}
# {'layer': 24, 'target': 14831, 'predicted': 14831, 'factual_label': 0, 'prob_clean': 0.987625777721405, 'prob_corrupted': 4.484229066292755e-05, 'prob_patched': 0.9821180105209351}
# {'layer': 24, 'target': 403, 'predicted': 403, 'factual_label': 0, 'prob_clean': 0.8936969041824341, 'prob_corrupted': 0.0012296481290832162, 'prob_patched': 0.9254742860794067}
# {'layer': 24, 'target': 5223, 'predicted': 5223, 'factual_label': 0, 'prob_clean': 0.9162746667861938, 'prob_corrupted': 0.0011649734806269407, 'prob_patched': 0.9119353890419006}
# {'layer': 24, 'target': 304, 'predicted': 304, 'factual_label': 0, 'prob_clean': 0.7694599032402039, 'prob_corrupted': 6.772766937501729e-05, 'prob_patched': 0.7390376925468445}
# {'layer': 24, 'target': 12364, 'predicted': 12364, 'factual_label': 0, 'prob_clean': 0.6193656325340271, 'prob_corrupted': 6.504687917185947e-05, 'prob_patched': 0.4169052541255951}
# {'layer': 24, 'target': 7642, 'predicted': 7642, 'factual_label': 0, 'prob_clean': 0.9476196765899658, 'prob_corrupted': 5.4418519539467525e-06, 'prob_patched': 0.840507447719574}
# {'layer': 24, 'target': 356, 'predicted': 356, 'factual_label': 0, 'prob_clean': 0.6792118549346924, 'prob_corrupted': 0.0005495514487847686, 'prob_patched': 0.6659828424453735}
# {'layer': 24, 'target': 415, 'predicted': 415, 'factual_label': 0, 'prob_clean': 0.5479787588119507, 'prob_corrupted': 8.423393410339486e-06, 'prob_patched': 0.5746136903762817}
# {'layer': 24, 'target': 25963, 'predicted': 25963, 'factual_label': 0, 'prob_clean': 0.8185117244720459, 'prob_corrupted': 0.0007793587865307927, 'prob_patched': 0.7727181315422058}
# {'layer': 24, 'target': 835, 'predicted': 835, 'factual_label': 0, 'prob_clean': 0.9221472144126892, 'prob_corrupted': 1.6622087059658952e-05, 'prob_patched': 0.8699870109558105}
# {'layer': 24, 'target': 4429, 'predicted': 4429, 'factual_label': 0, 'prob_clean': 0.9301221370697021, 'prob_corrupted': 0.318373441696167, 'prob_patched': 0.8887325525283813}
# {'layer': 24, 'target': 28740, 'predicted': 28740, 'factual_label': 0, 'prob_clean': 0.7809702754020691, 'prob_corrupted': 1.4071022633288521e-05, 'prob_patched': 0.712055504322052}
# {'layer': 24, 'target': 16662, 'predicted': 16662, 'factual_label': 0, 'prob_clean': 0.6804774403572083, 'prob_corrupted': 0.4195438027381897, 'prob_patched': 0.6448025703430176}
# {'layer': 24, 'target': 9039, 'predicted': 9039, 'factual_label': 0, 'prob_clean': 0.9974988102912903, 'prob_corrupted': 0.5390481948852539, 'prob_patched': 0.9967101812362671}
# {'layer': 24, 'target': 21013, 'predicted': 21013, 'factual_label': 0, 'prob_clean': 0.47355157136917114, 'prob_corrupted': 2.4547543375774694e-07, 'prob_patched': 0.4144653081893921}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.8882895112037659, 'prob_corrupted': 0.017977135255932808, 'prob_patched': 0.8251742720603943}
# {'layer': 24, 'target': 2264, 'predicted': 2264, 'factual_label': 0, 'prob_clean': 0.6173524260520935, 'prob_corrupted': 6.02106265432667e-05, 'prob_patched': 0.5258699655532837}
# {'layer': 24, 'target': 11003, 'predicted': 11003, 'factual_label': 0, 'prob_clean': 0.9976940751075745, 'prob_corrupted': 2.6508468309316413e-08, 'prob_patched': 0.9963127970695496}
# {'layer': 24, 'target': 7982, 'predicted': 7982, 'factual_label': 0, 'prob_clean': 0.9975983500480652, 'prob_corrupted': 1.9361665692940733e-07, 'prob_patched': 0.9973236322402954}
# {'layer': 24, 'target': 6642, 'predicted': 6642, 'factual_label': 0, 'prob_clean': 0.2998214066028595, 'prob_corrupted': 9.600425255484879e-05, 'prob_patched': 0.2677465081214905}
# {'layer': 24, 'target': 369, 'predicted': 369, 'factual_label': 0, 'prob_clean': 0.8826917409896851, 'prob_corrupted': 5.669365782523528e-05, 'prob_patched': 0.8694307804107666}
# {'layer': 24, 'target': 11821, 'predicted': 11821, 'factual_label': 0, 'prob_clean': 0.9562147259712219, 'prob_corrupted': 0.5446521043777466, 'prob_patched': 0.9430915713310242}
# {'layer': 24, 'target': 297, 'predicted': 297, 'factual_label': 0, 'prob_clean': 0.21669691801071167, 'prob_corrupted': 1.5104888916539494e-05, 'prob_patched': 0.20732547342777252}
# {'layer': 24, 'target': 14831, 'predicted': 14831, 'factual_label': 0, 'prob_clean': 0.9889562726020813, 'prob_corrupted': 3.352658313815482e-05, 'prob_patched': 0.9844042658805847}
# {'layer': 24, 'target': 264, 'predicted': 264, 'factual_label': 0, 'prob_clean': 0.9448027610778809, 'prob_corrupted': 2.972751644847449e-05, 'prob_patched': 0.9376962184906006}
# {'layer': 24, 'target': 5278, 'predicted': 5278, 'factual_label': 0, 'prob_clean': 0.8794687986373901, 'prob_corrupted': 0.007267553824931383, 'prob_patched': 0.8246077299118042}
# {'layer': 24, 'target': 5088, 'predicted': 5088, 'factual_label': 0, 'prob_clean': 0.9375372529029846, 'prob_corrupted': 4.654248186852783e-06, 'prob_patched': 0.9350382685661316}
# {'layer': 24, 'target': 356, 'predicted': 356, 'factual_label': 0, 'prob_clean': 0.9882292747497559, 'prob_corrupted': 2.5560973881511018e-05, 'prob_patched': 0.9886808395385742}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.7981520295143127, 'prob_corrupted': 1.1541360436240211e-05, 'prob_patched': 0.7811923027038574}
# {'layer': 24, 'target': 8725, 'predicted': 8725, 'factual_label': 0, 'prob_clean': 0.610698938369751, 'prob_corrupted': 0.00026090999017469585, 'prob_patched': 0.6047021746635437}
# {'layer': 24, 'target': 5783, 'predicted': 5783, 'factual_label': 0, 'prob_clean': 0.5911504626274109, 'prob_corrupted': 6.914181540196296e-06, 'prob_patched': 0.5872043967247009}
# {'layer': 24, 'target': 4320, 'predicted': 4320, 'factual_label': 0, 'prob_clean': 0.3622705042362213, 'prob_corrupted': 8.948183705115298e-08, 'prob_patched': 0.2359713315963745}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.6060084700584412, 'prob_corrupted': 2.2389522200683132e-05, 'prob_patched': 0.6159327030181885}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.9720895886421204, 'prob_corrupted': 4.954888936481439e-06, 'prob_patched': 0.9734687209129333}
# {'layer': 24, 'target': 20526, 'predicted': 20526, 'factual_label': 0, 'prob_clean': 0.9998993873596191, 'prob_corrupted': 0.022058039903640747, 'prob_patched': 0.9993720650672913}
# {'layer': 24, 'target': 297, 'predicted': 297, 'factual_label': 0, 'prob_clean': 0.9912059903144836, 'prob_corrupted': 1.4729896236076456e-07, 'prob_patched': 0.9846835732460022}
# {'layer': 24, 'target': 264, 'predicted': 264, 'factual_label': 0, 'prob_clean': 0.9972366094589233, 'prob_corrupted': 2.2504429580294527e-05, 'prob_patched': 0.9963485598564148}
# {'layer': 24, 'target': 10131, 'predicted': 10131, 'factual_label': 0, 'prob_clean': 0.9962847232818604, 'prob_corrupted': 0.00023855266044847667, 'prob_patched': 0.9958937168121338}
# {'layer': 24, 'target': 2918, 'predicted': 2918, 'factual_label': 0, 'prob_clean': 0.916463315486908, 'prob_corrupted': 0.5014022588729858, 'prob_patched': 0.916454017162323}
# {'layer': 24, 'target': 2056, 'predicted': 2056, 'factual_label': 0, 'prob_clean': 0.8600213527679443, 'prob_corrupted': 1.1879560588567983e-05, 'prob_patched': 0.8530364036560059}
# {'layer': 24, 'target': 1633, 'predicted': 1633, 'factual_label': 0, 'prob_clean': 0.9996756315231323, 'prob_corrupted': 1.577915895722981e-06, 'prob_patched': 0.9990906715393066}
# {'layer': 24, 'target': 438, 'predicted': 438, 'factual_label': 0, 'prob_clean': 0.8469947576522827, 'prob_corrupted': 2.5537137844366953e-06, 'prob_patched': 0.8078525066375732}
# {'layer': 24, 'target': 394, 'predicted': 394, 'factual_label': 0, 'prob_clean': 0.996960461139679, 'prob_corrupted': 0.00011414763139327988, 'prob_patched': 0.9961574673652649}
# {'layer': 24, 'target': 8993, 'predicted': 8993, 'factual_label': 0, 'prob_clean': 0.7399744987487793, 'prob_corrupted': 1.7480930182500742e-05, 'prob_patched': 0.778749942779541}
# {'layer': 24, 'target': 14714, 'predicted': 14714, 'factual_label': 0, 'prob_clean': 0.38119927048683167, 'prob_corrupted': 0.00026977097149938345, 'prob_patched': 0.2658798396587372}
# {'layer': 24, 'target': 11115, 'predicted': 11115, 'factual_label': 0, 'prob_clean': 0.6956138014793396, 'prob_corrupted': 5.433017577161081e-05, 'prob_patched': 0.608959972858429}
# {'layer': 24, 'target': 754, 'predicted': 754, 'factual_label': 0, 'prob_clean': 0.6555502414703369, 'prob_corrupted': 2.8360134820104577e-05, 'prob_patched': 0.6367537379264832}
# {'layer': 24, 'target': 7293, 'predicted': 7293, 'factual_label': 0, 'prob_clean': 0.9979925155639648, 'prob_corrupted': 4.228011312079616e-05, 'prob_patched': 0.994388997554779}
# {'layer': 24, 'target': 297, 'predicted': 297, 'factual_label': 0, 'prob_clean': 0.46566498279571533, 'prob_corrupted': 2.677679731277749e-05, 'prob_patched': 0.44946369528770447}
# {'layer': 24, 'target': 652, 'predicted': 652, 'factual_label': 0, 'prob_clean': 0.3875274956226349, 'prob_corrupted': 2.5970333808800206e-05, 'prob_patched': 0.31210997700691223}
# {'layer': 24, 'target': 3454, 'predicted': 3454, 'factual_label': 0, 'prob_clean': 0.8702170848846436, 'prob_corrupted': 0.00023614153906237334, 'prob_patched': 0.8298208713531494}
# {'layer': 24, 'target': 5783, 'predicted': 5783, 'factual_label': 0, 'prob_clean': 0.9890038371086121, 'prob_corrupted': 8.624130714451894e-06, 'prob_patched': 0.9884600639343262}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.9991150498390198, 'prob_corrupted': 2.27725558943348e-05, 'prob_patched': 0.9976792931556702}
# {'layer': 24, 'target': 356, 'predicted': 356, 'factual_label': 0, 'prob_clean': 0.9175205826759338, 'prob_corrupted': 2.350878821744118e-05, 'prob_patched': 0.909172773361206}
# {'layer': 24, 'target': 14019, 'predicted': 14019, 'factual_label': 0, 'prob_clean': 0.6153152585029602, 'prob_corrupted': 0.01521080732345581, 'prob_patched': 0.4728238582611084}
# {'layer': 24, 'target': 3654, 'predicted': 3654, 'factual_label': 0, 'prob_clean': 0.532216489315033, 'prob_corrupted': 4.348477887106128e-06, 'prob_patched': 0.4045920670032501}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.9816024899482727, 'prob_corrupted': 3.411226998650818e-07, 'prob_patched': 0.9805006980895996}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.9918099045753479, 'prob_corrupted': 1.8534972696215846e-05, 'prob_patched': 0.992197573184967}
# {'layer': 24, 'target': 20526, 'predicted': 20526, 'factual_label': 0, 'prob_clean': 0.9955991506576538, 'prob_corrupted': 0.0037426194176077843, 'prob_patched': 0.9927939176559448}
# {'layer': 24, 'target': 550, 'predicted': 550, 'factual_label': 0, 'prob_clean': 0.8786910772323608, 'prob_corrupted': 3.90706118196249e-05, 'prob_patched': 0.8825160264968872}
# {'layer': 24, 'target': 13969, 'predicted': 13969, 'factual_label': 0, 'prob_clean': 0.7131817936897278, 'prob_corrupted': 0.0005280250916257501, 'prob_patched': 0.6774936318397522}
# {'layer': 24, 'target': 5783, 'predicted': 5783, 'factual_label': 0, 'prob_clean': 0.5325047373771667, 'prob_corrupted': 6.935158307896927e-05, 'prob_patched': 0.5830156803131104}
# {'layer': 24, 'target': 264, 'predicted': 264, 'factual_label': 0, 'prob_clean': 0.8605231642723083, 'prob_corrupted': 4.934621028951369e-05, 'prob_patched': 0.8619269132614136}
# {'layer': 24, 'target': 2318, 'predicted': 2318, 'factual_label': 0, 'prob_clean': 0.8463350534439087, 'prob_corrupted': 0.009621857665479183, 'prob_patched': 0.86332768201828}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.9622104167938232, 'prob_corrupted': 0.06138703599572182, 'prob_patched': 0.9666537642478943}
# {'layer': 24, 'target': 264, 'predicted': 264, 'factual_label': 0, 'prob_clean': 0.7525632381439209, 'prob_corrupted': 0.0010452563874423504, 'prob_patched': 0.7465201616287231}
# {'layer': 24, 'target': 17734, 'predicted': 17734, 'factual_label': 0, 'prob_clean': 0.967216968536377, 'prob_corrupted': 0.00015539558080490679, 'prob_patched': 0.9580110311508179}
# {'layer': 24, 'target': 562, 'predicted': 562, 'factual_label': 0, 'prob_clean': 0.38095009326934814, 'prob_corrupted': 0.000432394357630983, 'prob_patched': 0.4924561381340027}
# {'layer': 24, 'target': 9638, 'predicted': 9638, 'factual_label': 0, 'prob_clean': 0.3224794268608093, 'prob_corrupted': 1.4638437278335914e-05, 'prob_patched': 0.31122785806655884}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.9992517828941345, 'prob_corrupted': 0.000372582784621045, 'prob_patched': 0.9987196922302246}
# {'layer': 24, 'target': 652, 'predicted': 652, 'factual_label': 0, 'prob_clean': 0.574664294719696, 'prob_corrupted': 1.2700900242634816e-06, 'prob_patched': 0.5793609619140625}
# {'layer': 24, 'target': 1736, 'predicted': 1736, 'factual_label': 0, 'prob_clean': 0.9063100218772888, 'prob_corrupted': 0.0012028029887005687, 'prob_patched': 0.8494653701782227}
# {'layer': 24, 'target': 403, 'predicted': 403, 'factual_label': 0, 'prob_clean': 0.2088610976934433, 'prob_corrupted': 1.8928265490103513e-05, 'prob_patched': 0.2119290977716446}
# {'layer': 24, 'target': 354, 'predicted': 354, 'factual_label': 0, 'prob_clean': 0.9318891763687134, 'prob_corrupted': 1.454389320088012e-08, 'prob_patched': 0.9404594898223877}
# {'layer': 24, 'target': 264, 'predicted': 264, 'factual_label': 0, 'prob_clean': 0.8288214802742004, 'prob_corrupted': 4.5957953261677176e-05, 'prob_patched': 0.8635356426239014}
# {'layer': 24, 'target': 369, 'predicted': 369, 'factual_label': 0, 'prob_clean': 0.7281109094619751, 'prob_corrupted': 3.344785363879055e-05, 'prob_patched': 0.7486330270767212}
# {'layer': 24, 'target': 4163, 'predicted': 4163, 'factual_label': 0, 'prob_clean': 0.37942376732826233, 'prob_corrupted': 1.0771435881906655e-05, 'prob_patched': 0.3607507050037384}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.9960139989852905, 'prob_corrupted': 0.00035691604716703296, 'prob_patched': 0.9963470101356506}
# {'layer': 24, 'target': 475, 'predicted': 475, 'factual_label': 0, 'prob_clean': 0.4430049657821655, 'prob_corrupted': 0.012677202932536602, 'prob_patched': 0.47838515043258667}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.8472471833229065, 'prob_corrupted': 1.7530743207316846e-05, 'prob_patched': 0.8604757785797119}
# {'layer': 24, 'target': 6297, 'predicted': 6297, 'factual_label': 0, 'prob_clean': 0.9278491139411926, 'prob_corrupted': 0.0010594736086204648, 'prob_patched': 0.8987680077552795}
# {'layer': 24, 'target': 28410, 'predicted': 28410, 'factual_label': 0, 'prob_clean': 0.9086083769798279, 'prob_corrupted': 0.0025998984929174185, 'prob_patched': 0.8372095823287964}
# {'layer': 24, 'target': 349, 'predicted': 349, 'factual_label': 0, 'prob_clean': 0.8785426616668701, 'prob_corrupted': 0.00019135538605041802, 'prob_patched': 0.7698509693145752}
# {'layer': 24, 'target': 264, 'predicted': 264, 'factual_label': 0, 'prob_clean': 0.9751631617546082, 'prob_corrupted': 0.1816626936197281, 'prob_patched': 0.9272878766059875}
# {'layer': 24, 'target': 521, 'predicted': 521, 'factual_label': 0, 'prob_clean': 0.8944234848022461, 'prob_corrupted': 0.034452471882104874, 'prob_patched': 0.7800448536872864}
# {'layer': 24, 'target': 798, 'predicted': 798, 'factual_label': 0, 'prob_clean': 0.9837490320205688, 'prob_corrupted': 7.089808917726259e-08, 'prob_patched': 0.9473603963851929}
# {'layer': 24, 'target': 19580, 'predicted': 19580, 'factual_label': 0, 'prob_clean': 0.9934379458427429, 'prob_corrupted': 0.01391102559864521, 'prob_patched': 0.9770911335945129}
# {'layer': 24, 'target': 2724, 'predicted': 2724, 'factual_label': 0, 'prob_clean': 0.9615647196769714, 'prob_corrupted': 5.118041372043081e-06, 'prob_patched': 0.9563716053962708}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.6889660954475403, 'prob_corrupted': 0.006585720926523209, 'prob_patched': 0.5772022604942322}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.9025298357009888, 'prob_corrupted': 0.00020966034207958728, 'prob_patched': 0.7742202877998352}
# {'layer': 24, 'target': 727, 'predicted': 727, 'factual_label': 0, 'prob_clean': 0.7880434393882751, 'prob_corrupted': 0.025336654856801033, 'prob_patched': 0.6743037104606628}
# {'layer': 24, 'target': 2525, 'predicted': 2525, 'factual_label': 0, 'prob_clean': 0.9787172675132751, 'prob_corrupted': 0.0003136362647637725, 'prob_patched': 0.9202732443809509}
# {'layer': 24, 'target': 506, 'predicted': 506, 'factual_label': 0, 'prob_clean': 0.49651646614074707, 'prob_corrupted': 3.770813418668695e-05, 'prob_patched': 0.41602393984794617}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.999413251876831, 'prob_corrupted': 0.0001373668637825176, 'prob_patched': 0.9901823401451111}
# {'layer': 24, 'target': 2444, 'predicted': 2444, 'factual_label': 0, 'prob_clean': 0.767928421497345, 'prob_corrupted': 0.0005603242316283286, 'prob_patched': 0.6822317242622375}
# {'layer': 24, 'target': 297, 'predicted': 297, 'factual_label': 0, 'prob_clean': 0.9971977472305298, 'prob_corrupted': 5.291972411214374e-05, 'prob_patched': 0.9694783091545105}
# {'layer': 24, 'target': 955, 'predicted': 955, 'factual_label': 0, 'prob_clean': 0.7545652985572815, 'prob_corrupted': 0.0008656429126858711, 'prob_patched': 0.7925984263420105}
# {'layer': 24, 'target': 415, 'predicted': 415, 'factual_label': 0, 'prob_clean': 0.7089199423789978, 'prob_corrupted': 0.0013190540485084057, 'prob_patched': 0.6505671739578247}
# {'layer': 24, 'target': 19580, 'predicted': 19580, 'factual_label': 0, 'prob_clean': 0.8128732442855835, 'prob_corrupted': 2.727710125327576e-05, 'prob_patched': 0.6951014399528503}
# {'layer': 24, 'target': 5651, 'predicted': 5651, 'factual_label': 0, 'prob_clean': 0.6540173888206482, 'prob_corrupted': 0.0002632316027302295, 'prob_patched': 0.4499254524707794}
# {'layer': 24, 'target': 297, 'predicted': 297, 'factual_label': 0, 'prob_clean': 0.9986593723297119, 'prob_corrupted': 0.4480364918708801, 'prob_patched': 0.9893984794616699}
# {'layer': 24, 'target': 264, 'predicted': 264, 'factual_label': 0, 'prob_clean': 0.9756231904029846, 'prob_corrupted': 0.000660663063172251, 'prob_patched': 0.9337078928947449}
# {'layer': 24, 'target': 297, 'predicted': 297, 'factual_label': 0, 'prob_clean': 0.9392557740211487, 'prob_corrupted': 9.015166870085523e-05, 'prob_patched': 0.8453006148338318}
# {'layer': 24, 'target': 367, 'predicted': 367, 'factual_label': 0, 'prob_clean': 0.9924341440200806, 'prob_corrupted': 0.0004455934977158904, 'prob_patched': 0.9386278390884399}
# {'layer': 24, 'target': 1450, 'predicted': 1450, 'factual_label': 0, 'prob_clean': 0.9914793968200684, 'prob_corrupted': 8.629067238530297e-09, 'prob_patched': 0.9681862592697144}
# {'layer': 24, 'target': 14488, 'predicted': 14488, 'factual_label': 0, 'prob_clean': 0.9951366782188416, 'prob_corrupted': 0.00018311358871869743, 'prob_patched': 0.9758796691894531}
# {'layer': 24, 'target': 506, 'predicted': 506, 'factual_label': 0, 'prob_clean': 0.41968289017677307, 'prob_corrupted': 0.0008346536196768284, 'prob_patched': 0.48067283630371094}
# {'layer': 24, 'target': 28740, 'predicted': 28740, 'factual_label': 0, 'prob_clean': 0.9997815489768982, 'prob_corrupted': 0.0005827413406223059, 'prob_patched': 0.9980065226554871}
# {'layer': 24, 'target': 521, 'predicted': 521, 'factual_label': 0, 'prob_clean': 0.98969966173172, 'prob_corrupted': 1.07222122096573e-05, 'prob_patched': 0.9245518445968628}
# {'layer': 24, 'target': 341, 'predicted': 341, 'factual_label': 0, 'prob_clean': 0.9995496869087219, 'prob_corrupted': 3.2686170436946327e-10, 'prob_patched': 0.993358314037323}
# {'layer': 24, 'target': 4273, 'predicted': 4273, 'factual_label': 0, 'prob_clean': 0.6871897578239441, 'prob_corrupted': 7.072582229739055e-05, 'prob_patched': 0.640671968460083}
# {'layer': 24, 'target': 304, 'predicted': 304, 'factual_label': 0, 'prob_clean': 0.9996040463447571, 'prob_corrupted': 0.4475271701812744, 'prob_patched': 0.9763972759246826}
# {'layer': 24, 'target': 264, 'predicted': 264, 'factual_label': 0, 'prob_clean': 0.997423529624939, 'prob_corrupted': 0.008607869036495686, 'prob_patched': 0.9682419300079346}
# {'layer': 24, 'target': 341, 'predicted': 341, 'factual_label': 0, 'prob_clean': 0.7644433379173279, 'prob_corrupted': 0.004398832097649574, 'prob_patched': 0.6985089778900146}
# {'layer': 24, 'target': 354, 'predicted': 354, 'factual_label': 0, 'prob_clean': 0.9998369216918945, 'prob_corrupted': 1.0645032233469465e-07, 'prob_patched': 0.9929323196411133}
# {'layer': 24, 'target': 11426, 'predicted': 11426, 'factual_label': 0, 'prob_clean': 0.5875266194343567, 'prob_corrupted': 0.00046211955486796796, 'prob_patched': 0.657324492931366}
# {'layer': 24, 'target': 905, 'predicted': 905, 'factual_label': 0, 'prob_clean': 0.7782486081123352, 'prob_corrupted': 0.017010878771543503, 'prob_patched': 0.8036454319953918}
# {'layer': 24, 'target': 28740, 'predicted': 28740, 'factual_label': 0, 'prob_clean': 0.417963445186615, 'prob_corrupted': 5.847858119523153e-05, 'prob_patched': 0.3585490584373474}
# {'layer': 24, 'target': 395, 'predicted': 395, 'factual_label': 0, 'prob_clean': 0.9969004392623901, 'prob_corrupted': 1.1800653965110541e-06, 'prob_patched': 0.9891260862350464}
# ...
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.3153778910636902, 'prob_corrupted': 2.903339009208139e-05, 'prob_patched': 0.3167707026004791}
# {'layer': 24, 'target': 302, 'predicted': 302, 'factual_label': 0, 'prob_clean': 0.9942183494567871, 'prob_corrupted': 2.6846309992833994e-05, 'prob_patched': 0.9937834739685059}
# {'layer': 24, 'target': 1250, 'predicted': 1250, 'factual_label': 0, 'prob_clean': 0.4913605749607086, 'prob_corrupted': 6.899060167597781e-07, 'prob_patched': 0.5991540551185608}
# {'layer': 24, 'target': 8000, 'predicted': 8000, 'factual_label': 0, 'prob_clean': 0.9537560939788818, 'prob_corrupted': 0.00015910623187664896, 'prob_patched': 0.9046586155891418}
# {'layer': 24, 'target': 3782, 'predicted': 3782, 'factual_label': 0, 'prob_clean': 0.9981447458267212, 'prob_corrupted': 0.009021015837788582, 'prob_patched': 0.9900318384170532}
# {'layer': 24, 'target': 15240, 'predicted': 15240, 'factual_label': 0, 'prob_clean': 0.6601883769035339, 'prob_corrupted': 7.004350482020527e-05, 'prob_patched': 0.5509926676750183}
# {'layer': 24, 'target': 4875, 'predicted': 4875, 'factual_label': 0, 'prob_clean': 0.7903710603713989, 'prob_corrupted': 0.36755090951919556, 'prob_patched': 0.8199905753135681}
# {'layer': 24, 'target': 486, 'predicted': 486, 'factual_label': 0, 'prob_clean': 0.9994926452636719, 'prob_corrupted': 0.006540399510413408, 'prob_patched': 0.998636782169342}
# {'layer': 24, 'target': 2223, 'predicted': 2223, 'factual_label': 0, 'prob_clean': 0.5400441884994507, 'prob_corrupted': 1.1813443052233197e-05, 'prob_patched': 0.4827443063259125}
# {'layer': 24, 'target': 5120, 'predicted': 5120, 'factual_label': 0, 'prob_clean': 0.9957570433616638, 'prob_corrupted': 0.31677332520484924, 'prob_patched': 0.9943627119064331}
# {'layer': 24, 'target': 14696, 'predicted': 14696, 'factual_label': 0, 'prob_clean': 0.9722955226898193, 'prob_corrupted': 3.965114228776656e-05, 'prob_patched': 0.9699752926826477}
# {'layer': 24, 'target': 6932, 'predicted': 6932, 'factual_label': 0, 'prob_clean': 0.9995574355125427, 'prob_corrupted': 0.00818211305886507, 'prob_patched': 0.9988573789596558}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.9699483513832092, 'prob_corrupted': 5.7402710808673874e-05, 'prob_patched': 0.9507027268409729}
# {'layer': 24, 'target': 2066, 'predicted': 2066, 'factual_label': 0, 'prob_clean': 0.8112860918045044, 'prob_corrupted': 4.344304670667043e-06, 'prob_patched': 0.860409140586853}
# {'layer': 24, 'target': 1760, 'predicted': 1760, 'factual_label': 0, 'prob_clean': 0.9968826770782471, 'prob_corrupted': 0.019467435777187347, 'prob_patched': 0.995900571346283}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.7394737005233765, 'prob_corrupted': 1.7292824850301258e-05, 'prob_patched': 0.7119818925857544}
# {'layer': 24, 'target': 1455, 'predicted': 1455, 'factual_label': 0, 'prob_clean': 0.9412398338317871, 'prob_corrupted': 9.825433835430886e-07, 'prob_patched': 0.9401471614837646}
# {'layer': 24, 'target': 297, 'predicted': 297, 'factual_label': 0, 'prob_clean': 0.9544464349746704, 'prob_corrupted': 1.3510871212929487e-05, 'prob_patched': 0.95759117603302}
# {'layer': 24, 'target': 8463, 'predicted': 8463, 'factual_label': 0, 'prob_clean': 0.9967474937438965, 'prob_corrupted': 0.010521646589040756, 'prob_patched': 0.996928870677948}
# {'layer': 24, 'target': 4875, 'predicted': 4875, 'factual_label': 0, 'prob_clean': 0.3216250240802765, 'prob_corrupted': 1.0753567039500922e-05, 'prob_patched': 0.29770374298095703}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.9978880286216736, 'prob_corrupted': 1.39325557029224e-05, 'prob_patched': 0.9979606866836548}
# {'layer': 24, 'target': 5683, 'predicted': 5683, 'factual_label': 0, 'prob_clean': 0.7444993257522583, 'prob_corrupted': 0.0001738958089845255, 'prob_patched': 0.7460176348686218}
# {'layer': 24, 'target': 304, 'predicted': 304, 'factual_label': 0, 'prob_clean': 0.5996674299240112, 'prob_corrupted': 3.973223670072912e-07, 'prob_patched': 0.5600608587265015}
# {'layer': 24, 'target': 9013, 'predicted': 9013, 'factual_label': 0, 'prob_clean': 0.9942578077316284, 'prob_corrupted': 1.1207117722733528e-07, 'prob_patched': 0.9959067106246948}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.8972055315971375, 'prob_corrupted': 3.4721153951977612e-06, 'prob_patched': 0.8948306441307068}
# {'layer': 24, 'target': 9691, 'predicted': 9691, 'factual_label': 0, 'prob_clean': 0.744251012802124, 'prob_corrupted': 5.78200415475294e-05, 'prob_patched': 0.754638671875}
# {'layer': 24, 'target': 8000, 'predicted': 8000, 'factual_label': 0, 'prob_clean': 0.9991814494132996, 'prob_corrupted': 4.79038420042599e-10, 'prob_patched': 0.9989105463027954}
# {'layer': 24, 'target': 3782, 'predicted': 3782, 'factual_label': 0, 'prob_clean': 0.9996576309204102, 'prob_corrupted': 4.22341690864414e-06, 'prob_patched': 0.9995953440666199}
# {'layer': 24, 'target': 835, 'predicted': 835, 'factual_label': 0, 'prob_clean': 0.4968467652797699, 'prob_corrupted': 0.0002353245363337919, 'prob_patched': 0.6545217037200928}
# {'layer': 24, 'target': 2651, 'predicted': 2651, 'factual_label': 0, 'prob_clean': 0.996392548084259, 'prob_corrupted': 0.03765328973531723, 'prob_patched': 0.9977228045463562}
# {'layer': 24, 'target': 390, 'predicted': 390, 'factual_label': 0, 'prob_clean': 0.9996016621589661, 'prob_corrupted': 4.0718180116527947e-07, 'prob_patched': 0.9997909665107727}
# {'layer': 24, 'target': 2645, 'predicted': 2645, 'factual_label': 0, 'prob_clean': 0.9563150405883789, 'prob_corrupted': 5.6264714658027515e-05, 'prob_patched': 0.9577549695968628}
# {'layer': 24, 'target': 403, 'predicted': 403, 'factual_label': 0, 'prob_clean': 0.8741694688796997, 'prob_corrupted': 1.1695932698785327e-05, 'prob_patched': 0.8886527419090271}
# {'layer': 24, 'target': 5822, 'predicted': 5822, 'factual_label': 0, 'prob_clean': 0.5644837021827698, 'prob_corrupted': 3.0231849450501613e-05, 'prob_patched': 0.5757109522819519}
# {'layer': 24, 'target': 378, 'predicted': 378, 'factual_label': 0, 'prob_clean': 0.8130319118499756, 'prob_corrupted': 2.962181042676093e-06, 'prob_patched': 0.8628919720649719}
# {'layer': 24, 'target': 3246, 'predicted': 3246, 'factual_label': 0, 'prob_clean': 0.8705947399139404, 'prob_corrupted': 1.5243194866343401e-05, 'prob_patched': 0.8811087012290955}
# {'layer': 24, 'target': 3081, 'predicted': 3081, 'factual_label': 0, 'prob_clean': 0.8624186515808105, 'prob_corrupted': 1.6237347608694108e-06, 'prob_patched': 0.9171237349510193}
# {'layer': 24, 'target': 369, 'predicted': 369, 'factual_label': 0, 'prob_clean': 0.5645166635513306, 'prob_corrupted': 5.41222561878385e-06, 'prob_patched': 0.47724539041519165}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.5668854117393494, 'prob_corrupted': 0.2734174132347107, 'prob_patched': 0.5420059561729431}
# {'layer': 24, 'target': 4875, 'predicted': 4875, 'factual_label': 0, 'prob_clean': 0.6949634552001953, 'prob_corrupted': 2.3271719328477047e-05, 'prob_patched': 0.703126072883606}
# {'layer': 24, 'target': 682, 'predicted': 682, 'factual_label': 0, 'prob_clean': 0.9354210495948792, 'prob_corrupted': 2.651919430718408e-06, 'prob_patched': 0.9555679559707642}
# {'layer': 24, 'target': 459, 'predicted': 459, 'factual_label': 0, 'prob_clean': 0.9911454319953918, 'prob_corrupted': 6.467334515036782e-06, 'prob_patched': 0.9909494519233704}
# {'layer': 24, 'target': 5556, 'predicted': 5556, 'factual_label': 0, 'prob_clean': 0.6160236597061157, 'prob_corrupted': 0.0014339271001517773, 'prob_patched': 0.6531188488006592}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.9131261706352234, 'prob_corrupted': 4.1564915591152385e-05, 'prob_patched': 0.9145497679710388}
# {'layer': 24, 'target': 7968, 'predicted': 7968, 'factual_label': 0, 'prob_clean': 0.4883473515510559, 'prob_corrupted': 6.550808757310733e-05, 'prob_patched': 0.6550807952880859}
# {'layer': 24, 'target': 302, 'predicted': 302, 'factual_label': 0, 'prob_clean': 0.43843767046928406, 'prob_corrupted': 1.3787060197500978e-05, 'prob_patched': 0.5008342266082764}
# {'layer': 24, 'target': 28750, 'predicted': 28750, 'factual_label': 0, 'prob_clean': 0.9999576807022095, 'prob_corrupted': 1.4910000345480512e-06, 'prob_patched': 0.9999200105667114}
# {'layer': 24, 'target': 12294, 'predicted': 12294, 'factual_label': 0, 'prob_clean': 0.9756504893302917, 'prob_corrupted': 8.87961323314812e-06, 'prob_patched': 0.972184956073761}
# {'layer': 24, 'target': 12768, 'predicted': 12768, 'factual_label': 0, 'prob_clean': 0.9992617964744568, 'prob_corrupted': 0.020390041172504425, 'prob_patched': 0.9993969202041626}
# {'layer': 24, 'target': 3236, 'predicted': 3236, 'factual_label': 0, 'prob_clean': 0.7843226194381714, 'prob_corrupted': 2.4853281388459436e-07, 'prob_patched': 0.781561017036438}
# {'layer': 24, 'target': 264, 'predicted': 264, 'factual_label': 0, 'prob_clean': 0.31526029109954834, 'prob_corrupted': 1.2410547242325265e-05, 'prob_patched': 0.34524157643318176}
# {'layer': 24, 'target': 9716, 'predicted': 9716, 'factual_label': 0, 'prob_clean': 0.28565114736557007, 'prob_corrupted': 0.07544403523206711, 'prob_patched': 0.28211042284965515}
# {'layer': 24, 'target': 298, 'predicted': 298, 'factual_label': 0, 'prob_clean': 0.9197431802749634, 'prob_corrupted': 5.153219717612956e-06, 'prob_patched': 0.9306334257125854}
# {'layer': 24, 'target': 6932, 'predicted': 6932, 'factual_label': 0, 'prob_clean': 0.9897236824035645, 'prob_corrupted': 0.9967256784439087, 'prob_patched': 0.9780208468437195}
# {'layer': 24, 'target': 378, 'predicted': 378, 'factual_label': 0, 'prob_clean': 0.666102409362793, 'prob_corrupted': 0.00017535673396196216, 'prob_patched': 0.7008242011070251}
# {'layer': 24, 'target': 403, 'predicted': 403, 'factual_label': 0, 'prob_clean': 0.2538587749004364, 'prob_corrupted': 0.0003602457290980965, 'prob_patched': 0.16743692755699158}
# {'layer': 24, 'target': 624, 'predicted': 624, 'factual_label': 0, 'prob_clean': 0.7280383706092834, 'prob_corrupted': 0.000269658281467855, 'prob_patched': 0.8345109224319458}
# {'layer': 24, 'target': 302, 'predicted': 302, 'factual_label': 0, 'prob_clean': 0.9976746439933777, 'prob_corrupted': 7.793403710820712e-06, 'prob_patched': 0.9983090162277222}
# {'layer': 24, 'target': 516, 'predicted': 516, 'factual_label': 0, 'prob_clean': 0.7838003635406494, 'prob_corrupted': 0.001445758156478405, 'prob_patched': 0.7956644892692566}
# {'layer': 24, 'target': 506, 'predicted': 506, 'factual_label': 0, 'prob_clean': 0.35442915558815, 'prob_corrupted': 0.3510340452194214, 'prob_patched': 0.33010369539260864}
# {'layer': 24, 'target': 297, 'predicted': 297, 'factual_label': 0, 'prob_clean': 0.8826035857200623, 'prob_corrupted': 1.8293479797648615e-06, 'prob_patched': 0.928943395614624}
# {'layer': 24, 'target': 1560, 'predicted': 1560, 'factual_label': 0, 'prob_clean': 0.6880474090576172, 'prob_corrupted': 0.00012255890760570765, 'prob_patched': 0.6845114827156067}
# {'layer': 24, 'target': 4594, 'predicted': 4594, 'factual_label': 0, 'prob_clean': 0.9661286473274231, 'prob_corrupted': 0.0026305057108402252, 'prob_patched': 0.9599263072013855}
# {'layer': 24, 'target': 304, 'predicted': 304, 'factual_label': 0, 'prob_clean': 0.5595947504043579, 'prob_corrupted': 1.773539224814158e-05, 'prob_patched': 0.7310327887535095}
# {'layer': 24, 'target': 13442, 'predicted': 13442, 'factual_label': 0, 'prob_clean': 0.9997585415840149, 'prob_corrupted': 0.8405683040618896, 'prob_patched': 0.9995599389076233}
# {'layer': 24, 'target': 562, 'predicted': 562, 'factual_label': 0, 'prob_clean': 0.6677521467208862, 'prob_corrupted': 0.010837928391993046, 'prob_patched': 0.7226998805999756}
# {'layer': 24, 'target': 3352, 'predicted': 3352, 'factual_label': 0, 'prob_clean': 0.5217960476875305, 'prob_corrupted': 4.806616801626695e-13, 'prob_patched': 0.5312196016311646}
# {'layer': 24, 'target': 684, 'predicted': 684, 'factual_label': 0, 'prob_clean': 0.3617291748523712, 'prob_corrupted': 2.654033960425295e-05, 'prob_patched': 0.3825185000896454}
# {'layer': 24, 'target': 272, 'predicted': 272, 'factual_label': 0, 'prob_clean': 0.8369054794311523, 'prob_corrupted': 1.5518009604420513e-05, 'prob_patched': 0.887876570224762}
# {'layer': 24, 'target': 4875, 'predicted': 4875, 'factual_label': 0, 'prob_clean': 0.7043389081954956, 'prob_corrupted': 4.574742888507899e-06, 'prob_patched': 0.8229674100875854}
# {'layer': 24, 'target': 741, 'predicted': 741, 'factual_label': 0, 'prob_clean': 0.6638984680175781, 'prob_corrupted': 0.00027177963056601584, 'prob_patched': 0.7602736949920654}
# {'layer': 24, 'target': 378, 'predicted': 378, 'factual_label': 0, 'prob_clean': 0.9565116167068481, 'prob_corrupted': 0.9576675891876221, 'prob_patched': 0.9692162275314331}
# {'layer': 24, 'target': 1368, 'predicted': 1368, 'factual_label': 0, 'prob_clean': 0.8445409536361694, 'prob_corrupted': 0.0001694875827524811, 'prob_patched': 0.8082191944122314}
# {'layer': 24, 'target': 2663, 'predicted': 2663, 'factual_label': 0, 'prob_clean': 0.9314602613449097, 'prob_corrupted': 3.1269613828044385e-05, 'prob_patched': 0.9132398962974548}
# {'layer': 24, 'target': 4622, 'predicted': 4622, 'factual_label': 0, 'prob_clean': 0.24626290798187256, 'prob_corrupted': 2.9934327017144824e-07, 'prob_patched': 0.27001678943634033}
# {'layer': 24, 'target': 369, 'predicted': 369, 'factual_label': 0, 'prob_clean': 0.8458899855613708, 'prob_corrupted': 0.1888546496629715, 'prob_patched': 0.8364468216896057}
# {'layer': 24, 'target': 459, 'predicted': 459, 'factual_label': 0, 'prob_clean': 0.9973912239074707, 'prob_corrupted': 0.0006301826215349138, 'prob_patched': 0.9969937801361084}
# {'layer': 24, 'target': 576, 'predicted': 576, 'factual_label': 0, 'prob_clean': 0.9953837990760803, 'prob_corrupted': 3.088305311393924e-05, 'prob_patched': 0.9952612519264221}
# {'layer': 24, 'target': 2082, 'predicted': 2082, 'factual_label': 0, 'prob_clean': 0.9976805448532104, 'prob_corrupted': 4.657495537685463e-06, 'prob_patched': 0.9973464012145996}
# {'layer': 24, 'target': 2066, 'predicted': 2066, 'factual_label': 0, 'prob_clean': 0.9992054104804993, 'prob_corrupted': 5.2489784138742834e-05, 'prob_patched': 0.9990659356117249}
#     layer_0   layer_1   layer_2   layer_3   layer_4   layer_5   layer_6  \
# 0  1.294509  0.588123  0.599537  0.629491  0.628426  0.633355  0.641212
# 1  0.694644  0.728703  0.729195  0.756930  0.770500  0.774744  0.783276
# 2  0.396447  0.593714  0.617335  0.708454  0.709362  0.721815  0.715236
# 3  0.985408  0.985426  0.984710  0.982716  0.983901  0.982470  0.981831
# 4  0.860786  0.920226  0.934292  0.965735  0.960764  0.965666  0.975834
# 5  0.763542  0.698114  0.685705  0.659408  0.657956  0.657452  0.652198
#
#     layer_7   layer_8   layer_9  ...  layer_23  layer_24  layer_25  layer_26  \
# 0  0.656767  0.830203  0.833690  ...  0.940847  0.935663  0.944678  0.930630
# 1  0.802638  0.849864  0.890624  ...  0.994173  1.022769  0.985977  0.989619
# 2  0.714184  0.730314  0.727629  ...  0.908291  0.919717  0.927912  0.926533
# 3  0.982571  0.985732  0.987569  ...  0.994278  1.002007  1.002559  1.001664
# 4  1.005919  1.027618  1.012597  ...  1.264150  1.282962  1.308478  1.305278
# 5  0.648127  0.648115  0.648477  ...  0.660576  0.654621  0.654255  0.663908
#
#    layer_27  layer_28  layer_29  layer_30  layer_31              Token
# 0  0.944111  0.941764  0.945764  0.964816       1.0      factual_first
# 1  1.001927  1.003305  0.945034  0.974604       1.0   nonfactual_first
# 2  0.953111  0.967957  0.985470  0.998928       1.0     factual_middle
# 3  1.001609  1.002578  1.002988  1.000559       1.0  nonfactual_middle
# 4  1.250628  1.347407  1.124703  0.997176       1.0       factual_last
# 5  0.701212  0.718355  0.896299  0.971098       1.0    nonfactual_last
#
# [6 rows x 33 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


fig, axes = plt.subplots(2, 1, figsize=(20, 10), gridspec_kw={'hspace': 0.3})

df_dict_plot_factual = df_dict_patching[df_dict_patching['Token'].isin(['factual_first',
                                                      'factual_middle',
                                                      'factual_last'])]
df_dict_plot_factual.set_index('Token', inplace=True)
sns.heatmap(df_dict_plot_factual, annot=True, fmt=".2f", cmap="YlGnBu", vmin=0.2, vmax=1, ax = axes[0])


df_dict_plot_nonfactual = df_dict_patching[df_dict_patching['Token'].isin(['nonfactual_first',
                                                      'nonfactual_middle',
                                                      'nonfactual_last'])]
df_dict_plot_nonfactual.set_index('Token', inplace=True)
sns.heatmap(df_dict_plot_nonfactual, annot=True, fmt=".2f", cmap="YlGnBu", vmin=0.2, vmax=1, ax = axes[1])

# Add labels and title
plt.xlabel("Layers")
plt.ylabel("Tokens")
plt.title("Heatmap of Tokens vs Layers")

# Show plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# df_dict_plot.set_index('Token', inplace=True)
plt.figure(figsize=(20, 6))
# Create a heatmap
df_dict_plot_nonfactual = df_dict_plot[df_dict_plot['Token'].isin(['nonfactual_first',
                                                      'nonfactual_middle',
                                                      'nonfactual_last'])]
df_dict_plot_nonfactual.set_index('Token', inplace=True)
sns.heatmap(df_dict_plot_nonfactual, annot=True, fmt=".2f", cmap="YlGnBu", vmin=0, vmax=1)

# Add labels and title
plt.xlabel("Layers")
plt.ylabel("Tokens")
plt.title("Heatmap of Tokens vs Layers")

# Show plot
plt.show()

# %%
df_dict_plot_factual
